# %% [markdown]
# ## 파싱(Parsing)이란?
#
# **'파싱'** 이란 문자의 구조를 분석해서 원하는 정보를 얻어내는걸 말함
# 복잡한 HTML 코드에서 정보를 뽑아내는 것도 파싱의 일종
#
# ## Beautiful Soup
#
# 파이썬에서는 Beautiful Soup 을 통해 HTML을 파싱한다.
#
# 파싱할 HTML 코드를 변수 ``html_code``에 넣는다(파이썬에서 여러줄의 텍스트는 """와 """ 사이에 두면 하나의 문자열로 인식)

# %%
import requests

response = requests.get('https://workey.codeit.kr/ratings/index')
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <title>티비랭킹닷컴</title>
#   <meta charset="utf-8">
#   <link href="https://fonts.googleapis.com/css?family=Noto+Sans+KR" rel="stylesheet">
#   <style>
#     /* body start */
#     body {
#       font-family: 'Noto Sans KR', sans-serif;
#       margin: 0;
#     }
#
#     /* navigation bar start */
#     .nav-bar {
#       position: fixed;
#       width: 100%;
#       padding-top: 10px;
#       padding-bottom: 10px;
#       background-color: #ffffff;
#       box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.14);
#       z-index: 1;
#     }
#
#     .nav-bar #tv-image {
#       margin-left: 78px;
#       margin-right: 15px;
#       height: 36px;
#       vertical-align: middle;
#     }
#
#     .nav-bar span {
#       font-weight: bold;
#       color: #4a4a4a;
#     }
#
#     /* date picker start */
#     .date-pick {
#       padding-top: 56px;
#       height: 200px;
#       background-color: #efefef;
#       margin-left: auto;
#       margin-right: auto;
#       position: relative;
#     }
#
#     .date-pick .search-box {
#       text-align: center;
#       position: absolute;
#       display: block;
#       left: 50%;
#       transform: translateX(-50%);
#     }
#
#     .date-pick .search-box p {
#       text-align: left;
#     }
#
#     .date-pick .search-box select {
#       padding: 4px;
#     }
#
#     .date-pick .search-box .search-btn {
#       display: inline-block;
#       margin-left: 20px;
#       padding: 3px 28px 4px 28px;
#       border-radius: 4px;
#       background-color: #00a9dc;
#       font-weight: 300;
#       font-size: 13.333px;
#       height: 27px;
#       box-sizing: border-box;
#       color: #ffffff;
#     }
#
#     /* main body start */
#
#     .container {
#       margin-left: auto;
#       margin-right: auto;
#     }
#
#     .row.top-table {
#       background-color: #00a9dc;
#       color: #ffffff;
#       padding-top: 20px;
#       padding-bottom: 20px;
#     }
#
#     table {
#       border-collapse: collapse;
#       border-spacing: 2px;
#       font-size: 16px;
#     }
#
#     td, th {
#       display: table-cell;
#       color: #4a4a4a;
#     }
#
#     .row .rank {
#       padding-left: 25px;
#     }
#
#     .row .channel {
#       padding-left: 58px;
#     }
#
#     .row .program {
#       padding-left: 41px;
#     }
#
#     .row .percent {
#       color: #00a9dc;
#       padding-left: 100px;
#     }
#
#     .top-table.row * {
#       color: #ffffff;
#       font-weight: 300;
#     }
#
#     .top-table.row .rank {
#       padding-left: 17px;
#       padding-right: 17px;
#     }
#
#     .top-table.row .channel {
#       padding-right: 58px;
#     }
#
#     .top-table.row .program {
#       padding-right: 41px;
#     }
#
#     .top-table.row .percent {
#       padding-right: 28px;
#     }
#
#     .header-row {
#       min-width: 391px;
#       display: inline-block;
#       text-align: center;
#     }
#   </style>
# </head>
# <body>
# <script src="https://code.jquery.com/jquery-3.2.1.min.js"
#         integrity="sha256-hwg4gsxgFZhOsEEamdOYGBf13FyQuiTwlAQgxVSNgt4="
#         crossorigin="anonymous">
# </script>
#
# <!-- NAVIGATION BAR -->
# <div class="nav-bar">
#   <img src="/images/nielsen/group.png" id='tv-image'>
#   <span>TV Ranking.com</span>
# </div>
# <!-- DATE PICKER -->
# <div class='date-pick'>
#   <div style="height:55px;"></div>
#   <div class='search-box'>
#     <p style="font-size: 16px;color:#4a4a4a;margin-bottom: 4px;">날짜 검색</p>
#     <section class="header-row">
#       <select name="year" style="padding-right: 32px" class="getYear">
#         <option selected="selected">2010</option>
#         <option>2011</option>
#         <option>2012</option>
#         <option>2013</option>
#         <option>2014</option>
#         <option>2015</option>
#         <option>2016</option>
#         <option>2017</option>
#         <option>2018</option>
#       </select>
#       <select class="getMonth" name="month" style="padding-right: 32px">
#         <option selected="selected">1</option>
#         <option>2</option>
#         <option>3</option>
#         <option>4</option>
#         <option>5</option>
#         <option>6</option>
#         <option>7</option>
#         <option>8</option>
#         <option>9</option>
#         <option>10</option>
#         <option>11</option>
#         <option>12</option>
#       </select>
#       <select id="weekSelectBox">
#         <option value="0" selected="selected">2009.12.28 ~ 2010.01.03</option>
#         <option value="1">2010.01.04 ~ 2010.01.10</option>
#         <option value="2">2010.01.11 ~ 2010.01.17</option>
#         <option value="3">2010.01.18 ~ 2010.01.24</option>
#         <option value="4">2010.01.25 ~ 2010.01.31</option>
#       </select>
#       <div class="search-btn">
#         search
#       </div>
#     </section>
#   </div>
# </div>
#
# <!-- MAIN BODY -->
# <div class="container">
#   <div class="box">
#     <p style="font-size:18px;color:#4a4a4a;text-align: center;margin-top:60px; margin-bottom:15px;">가구시청률 TOP 10</p>
#     <p style="font-size:14px;color:#9b9b9b;text-align: center;margin-bottom:25px">(분석기준: National, 유료플랫폼 가입 기구,
#       단위:%)</p>
#     <table style="margin-left: auto;margin-right: auto;" cellpadding="7">
#       <tr height="64" class="top-table row">
#         <th class="rank">순위</th>
#         <th class="channel">채널</th>
#         <th class="program">프로그램</th>
#         <th class="percent">시청률</th>
#       </tr>
#       <tr class="row">
#         <td class="rank">1</td>
#         <td class="channel">KBS2</td>
#         <td class="program">주말연속극(수상한삼형제)</td>
#         <td class="percent">33.4</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">2</td>
#         <td class="channel">KBS1</td>
#         <td class="program">일일연속극(다함께차차차)</td>
#         <td class="percent">33.1</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">3</td>
#         <td class="channel">KBS2</td>
#         <td class="program">해피선데이</td>
#         <td class="percent">27.1</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">4</td>
#         <td class="channel">MBC</td>
#         <td class="program">MBC연기대상2부</td>
#         <td class="percent">24.4</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">5</td>
#         <td class="channel">SBS</td>
#         <td class="program">주말극장(천만번사랑해)</td>
#         <td class="percent">24.2</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">6</td>
#         <td class="channel">MBC</td>
#         <td class="program">MBC방송연예대상2부</td>
#         <td class="percent">24.0</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">7</td>
#         <td class="channel">MBC</td>
#         <td class="program">MBC방송연예대상1부</td>
#         <td class="percent">22.4</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">8</td>
#         <td class="channel">SBS</td>
#         <td class="program">SBS연예대상2부</td>
#         <td class="percent">21.1</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">9</td>
#         <td class="channel">MBC</td>
#         <td class="program">주말기획드라마(보석비빔밥)</td>
#         <td class="percent">20.9</td>
#       </tr>
#       <tr class="row">
#         <td class="rank">10</td>
#         <td class="channel">MBC</td>
#         <td class="program">일일시트콤(지붕뚫고하이킥)</td>
#         <td class="percent">19.9</td>
#       </tr>
#     </table>
#   </div>
# </div>
# <script>
#   $(".getMonth, .getYear").on("change", function () {
#     window.location.assign("/ratings/index?year=" + $(".getYear").val() + "&month=" + $(".getMonth").val() + "&weekIndex=0");
#
#   });
#   $(".search-btn").on("click", function () {
#     var index = $("#weekSelectBox").val();
#     window.location.assign("/ratings/index?year=" + $(".getYear").val() + "&month=" + $(".getMonth").val() + "&weekIndex=" + index);
#   });
# </script>
# </body>
# </html>

# %%
html_code = """<!DOCTYPE html>
<html>
<head>
    <title>Sample Website</title>
</head>
<body>
<h2>HTML 연습!</h2>

<p>이것은 첫 번째 문단입니다.</p>
<p>이것은 두 번째 문단입니다!</p>

<ul>
    <li>커피</li>
    <li>녹차</li>
    <li>우유</li>
</ul>

<img src='https://i.imgur.com/bY0l0PC.jpg' alt="coffee"/>
<img src='https://i.imgur.com/fvJLWdV.jpg' alt="green-tea"/>
<img src='https://i.imgur.com/rNOIbNt.jpg' alt="milk"/>

</body>
</html>
"""

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# HTML코드를 파싱하기 위해서는 HTML을 BeautifulSoup 타입으로 바꿔줘야한다.

# %%
soup = BeautifulSoup(html_code, 'html.parser')

# type 출력
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
tags = soup.select('li')

# %%
print(tags)
# Out:
# [<li>커피</li>, <li>녹차</li>, <li>우유</li>]

# %% [markdown]
# 여기서 첫번쨰 ``<li>`` 태그만 출력해보자

# %%
print(tags[0])
# Out:
# <li>커피</li>

# %% [markdown]
# ``.select()`` 로 가져온 태그는 사실 그냥 텍스트가 아니다

# %%
print(type(tags[0]))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# 위와 같이 text가 아닌 엘리먼트 태그라는 형식의 type이 출력된다.
#
# 이걸 BeautifulSoup 태그라고 부르자
#
# 여기서 ``.text``라고 붙이면 텍스트만 추출할 수 있다.

# %%
# 모든 li 태그 선택
tags = soup.select('li')

# 첫 번째 <li> 태그 출력하기
print(tags[0])

# 첫 번째 <li> 태그의 텍스트 출력하기
print(tags[0].text)
# Out:
# <li>커피</li>
# 커피

# %%
# 반복문을 사용하여 모든 문자열을 추출해서 리스트에 담자
tags = soup.select('li')

beverage_names = []

for li in tags:
    beverage_names.append(li.text)
    
print(beverage_names)
# Out:
# ['커피', '녹차', '우유']

# %% [markdown]
# ## 파싱(Parsing) II
#
# 이번에는 태그의 속성 값을 추출해보자
#
# ``<img>`` 태그의 ``src`` 속성에는 일반적으로 이미지 주소가 저장되어 있다.

# %%
from bs4 import BeautifulSoup

html_code = """<!DOCTYPE html>
<html>
<head>
    <title>Sample Website</title>
</head>
<body>
<h2>HTML 연습!</h2>

<p>이것은 첫 번째 문단입니다.</p>
<p>이것은 두 번째 문단입니다!</p>

<ul>
    <li>커피</li>
    <li>녹차</li>
    <li>우유</li>
</ul>

<img src='https://i.imgur.com/bY0l0PC.jpg' alt="coffee"/>
<img src='https://i.imgur.com/fvJLWdV.jpg' alt="green-tea"/>
<img src='https://i.imgur.com/rNOIbNt.jpg' alt="milk"/>

</body>
</html>
"""

# BeautifulSoup 타입으로 전환
soup = BeautifulSoup(html_code, 'html.parser')

# 모든 <img> 태그 선택하기
img_tags = soup.select('img')


print(img_tags)
# Out:
# [<img alt="coffee" src="https://i.imgur.com/bY0l0PC.jpg"/>, <img alt="green-tea" src="https://i.imgur.com/fvJLWdV.jpg"/>, <img alt="milk" src="https://i.imgur.com/rNOIbNt.jpg"/>]

# %% [markdown]
# 위와 같이 img 링크의 리스트가 출력된다.
#
# 이 중에서 첫 번쨰 img 태그만 꺼내보자

# %%
img_tags = soup.select('img')

# 이 중 첫 번째 요소 출력하기
print(img_tags[0])
# Out:
# <img alt="coffee" src="https://i.imgur.com/bY0l0PC.jpg"/>

# %% [markdown]
# 태그에 ``.text`` 를 붙이면 텍스트가 추출된 것처럼, 태그에 ``["속성 이름"]`` 을 붙여주면 해당 속성의 값을 가져올 수 있다.

# %%
img_tags = soup.select('img')

print(img_tags[0]['src'])
# Out:
# https://i.imgur.com/bY0l0PC.jpg

# %% [markdown]
# 위와 같이 이미지의 주소만 출력된다.
#
# ``for``반목문을 활용하면 모든 이미지 주소를 가져올 수 있을 것

# %%
img_tags = soup.select('img')

imgs = []

for img in img_tags:
    imgs.append(img["src"])
    
print(imgs)
# Out:
# ['https://i.imgur.com/bY0l0PC.jpg', 'https://i.imgur.com/fvJLWdV.jpg', 'https://i.imgur.com/rNOIbNt.jpg']

# %% [markdown]
# ## CSS 선택자 더 알아보기
#
# 앞서 네가지의 CSS 선택자를 알아보았다.
#
# ### OR 연산
#
# 쉼표( , )는 OR 연산을 의미한다.
#
# ``
# two, four {
#   color: red;
# }``
#
# ### AND 연산
#
# 두 CSS 선택자를 붙여쓰면, 두 조건에 모두 해당되는 요소를 선택한다.
#
# ``
# .favorite.private {
#   color: red;
# }``
#
# ### 중첩된 요소
#
# HTML 태그 안에 또 다른 HTML 태그가 있을 수 있다. 이를 태그가 중첩되어 있다고 하는데
# 일반적인 웹 페이지의 HTML 태그를 많이 중첩되어 있기 때문에 중첩에 대한 조건을 추가하는 경우가 많다.
#
# ``
# <i>디저트</i>
# <p>
#   <i>다쿠아즈</i>
#   <i>마카롱</i>
#   <i>케이크</i>
# </p>
# ``
# ``<i>`` 태그를 이탤릭체를 효과를 의미하는데
# 위 코드를 보면 여러개의 ``<i>`` 태그가 중첩되어 있음을 볼 수 있다.
#
# 이때 만약 ``<p>`` 태그 안에 중첩된 ``<i>``태그만 가져오고 싶다면 어떻게 해야할까?
#
# 이런 경우 띄어쓰기로 중첩을 표현할 수 있다.
#
# ``p i{
#     color: red;
# }
#     ``

# %% [markdown]
# ## 크롬 개발자 도구로 선택자 알아내기
#
# 조금 더 쉽게 HTML 태그의 구조를 알아내려면?
#
# 크롬 브라우저의 개발자 도구를 사용하면 된다.

# %% [markdown]
# ## 파싱(Parsing) III
#
# 이번에는 실제 웹사이트의 reponse를 받아서 파싱해보자
#
# ### HTML 코드 받아오기
#
# 먼저 웹사이트의 HTML 코드를 받아오자
#
# (이번 실습에서는 코드잇 음악차트를 이용할 것)

# %%
import requests

response = requests.get("https://workey.codeit.kr/music/index")

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <script src="https://cdn.jsdelivr.net/npm/vue/dist/vue.js"></script>
#   <script src="https://unpkg.com/axios/dist/axios.min.js"></script>
#   <meta charset="UTF-8">
#   <title>Codeit Music</title>
#   <style>
#     body {
#       margin: 0;
#     }
#
#     a {
#       text-decoration: none;
#       color: inherit;
#     }
#
#     img {
#       vertical-align: middle;
#     }
#
#     ul {
#       list-style: none;
#       padding: 0;
#       margin: 0;
#     }
#
#     * {
#       box-sizing: border-box;
#     }
#
#     .header {
#       position: fixed;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 60px;
#       background-color: #ffffff;
#       overflow: hidden;
#       z-index: 1;
#     }
#
#     .nav-warpper {
#       max-width: 1163px;
#       margin: 0 auto;
#       height: 100%;
#       line-height: 60px;
#       padding: 0 20px
#     }
#
#     .header__logo .logo-img {
#       width: 34px;
#       margin-right: 25px;
#     }
#
#     .header__nav {
#       display: inline-block;
#       vertical-align: middle;
#     }
#
#     .header__nav .menu {
#       float: left;
#       font-size: 16px;
#       color: #4a4a4a;
#       margin-right: 21px;
#     }
#
#     .header__search {
#       display: inline-block;
#       vertical-align: middle;
#       margin: 0 53px;
#       width: 397px;
#       height: 36px;
#       line-height: 36px;
#       border-radius: 22px;
#       border: 1px solid #4a90e2;
#       padding: 0 13px;
#     }
#
#     .header__search .icon {
#       width: 24px;
#       margin-right: 4px;
#     }
#
#     .header__search .input {
#       border: none;
#       outline: none;
#       font-size: 14px;
#       background: transparent;
#       width: calc(100% - 35px);
#     }
#
#     .header__user {
#       display: inline-block;
#       float: right;
#     }
#
#     .header__user .name {
#       font-size: 14px;
#       color: #4a4a4a;
#       margin-right: 14px;
#     }
#
#     .header__user .profile {
#       width: 30px;
#     }
#
#     .main {
#       min-height: calc(100vh - 60px);
#       padding-top: 60px;
#       background-color: #fafafa;
#       position: relative;
#       overflow: hidden;
#     }
#
#     .main section {
#       float: left;
#     }
#
#     .contents-warpper {
#       max-width: 991px;
#       margin: 0 auto;
#       padding: 34px 0;
#     }
#
#     .main__sidebar {
#       width: 231px;
#       margin-right: 23px;
#     }
#
#     .main__sidebar article {
#       width: 100%;
#       border-radius: 7px;
#       background-color: #ffffff;
#       padding: 17px 13px 5px;
#       margin-bottom: 32px;
#     }
#
#     .main__sidebar .popular__title,
#     .main__sidebar .rank__title {
#       margin: 0 0 24px;
#       font-size: 14px;
#       font-weight: bold;
#       color: #4a4a4a;
#     }
#
#     .main__sidebar .list {
#       font-size: 14px;
#       color: #4a4a4a;
#       margin-bottom: 12px;
#     }
#
#     .main__sidebar .list__index {
#       display: inline-block;
#       width: 18px;
#       height: 18px;
#       line-height: 1.8;
#       text-align: center;
#       font-size: 11px;
#       font-weight: bold;
#       border-radius: 6px;
#       color: #ffffff;
#       background-color: #dbdbdb;
#     }
#
#     .main__sidebar .list__index.blue {
#       background-color: #2391e9;
#     }
#
#     .main__sidebar .popular__order .list__index {
#       margin-right: 18px;
#     }
#
#     .main__sidebar .rank__order .list__index {
#       margin-right: 10px;
#     }
#
#     .main__sidebar .list__rating {
#       font-size: 14px;
#       font-weight: normal;
#       color: #9b9b9b;
#       text-align: center;
#       width: 25px;
#       display: inline-block;
#     }
#
#     .main__sidebar .und {
#       width: 8px;
#       vertical-align: unset;
#       margin-right: 2px;
#     }
#
#     .main__sidebar .dash {
#       display: inline-block;
#       width: 6px;
#       height: 1px;
#       background-color: #979797;
#       vertical-align: super;
#       margin-right: 3px;
#       margin-left: 1px;
#     }
#
#     .main__listWrapper {
#       width: 737px;
#     }
#
#     .main__listWrapper .playlist {
#       width: 100%;
#       height: 240px;
#       border-radius: 7px;
#       box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15);
#       position: relative;
#       overflow: hidden;
#       background-color: #ffffff;
#       margin-bottom: 34px;
#     }
#
#     .main__listWrapper .playlist__theme {
#       width: 68px;
#       border-bottom: 1px solid #ffffff;
#       position: absolute;
#       top: 23px;
#       left: 26px;
#       margin: 0;
#       color: #ffffff;
#       text-align: center;
#       padding-bottom: 8px;
#       font-size: 14px;
#       font-weight: bold;
#     }
#
#     .main__listWrapper .playlist__img {
#       width: 397px;
#       float: left;
#     }
#
#     .main__listWrapper .playlist__meta {
#       padding: 22px 19px;
#       float: left;
#       width: 340px;
#     }
#
#     .main__listWrapper .playlist__meta .owner {
#       width: 60px;
#       float: left;
#       margin-right: 15px;
#     }
#
#     .main__listWrapper .playlist__meta .title {
#       margin: 0;
#       font-size: 20px;
#       font-weight: normal;
#       color: #4a4a4a;
#       word-break: keep-all;
#       height: 48px;
#     }
#
#     .main__listWrapper .playlist__meta .tags {
#       margin: 45px 0 16px;
#       padding-bottom: 15px;
#       border-bottom: 1px solid #9b9b9b;
#       color: #9b9b9b;
#       font-size: 14px;
#       line-height: 1.7;
#     }
#
#     .main__listWrapper .playlist__meta .data img {
#       width: 20px;
#     }
#
#     .main__listWrapper .playlist__meta .data span {
#       vertical-align: middle;
#       margin-left: 6px;
#       margin-right: 16px;
#     }
#
#     @media (max-width: 991px) {
#       body * {
#         display: none;
#       }
#
#       body {
#         width: 100vw;
#         height: 100vh;
#         background-color: rgba(0, 0, 0, 0.8);
#       }
#
#       body::after {
#         display: block;
#         content: '지원하지 않는 화면 크기 입니다. 브라우저 크기를 넓혀주세요.';
#         position: absolute;
#         top: 50%;
#         left: 50%;
#         width: 230px;
#         word-break: keep-all;
#         text-align: center;
#         line-height: 1.7;
#         font-size: 18px;
#         color: #ffffff;
#         transform: translate(-50%, -50%);
#       }
#     }
#   </style>
# </head>
# <body>
# <header class="header">
#   <nav class="nav-warpper">
#     <a class="header__logo" href="#"><img class="logo-img" src="/images/music/logo.png" alt="logo"/></a>
#     <ul class="header__nav">
#       <li class="menu"><a href="#">인기차트</a></li>
#       <li class="menu"><a href="#">추천음악</a></li>
#       <li class="menu"><a href="#">뮤직비디오</a></li>
#     </ul>
#     <div class="header__search">
#       <img class="icon" src="/images/music/search.png"/>
#       <input class="input" type="text" placeholder="오늘은 무슨 음악을 들을까?"/>
#     </div>
#     <div class="header__user">
#       <span class="name">강영훈</span>
#       <img class="profile" src="/images/music/user.png" alt="user"/>
#     </div>
#   </nav>
# </header>
# <div class="main">
#   <div class="contents-warpper">
#     <section class="main__sidebar">
#       <article class="popular">
#         <h3 class="popular__title">인기 아티스트</h3>
#         <ul class="popular__order">
#           <li class="list">
#             <span class="list__index blue">1</span> 아이유 (IU)
#           </li>
#           <li class="list">
#             <span class="list__index blue">2</span> 방탄소년단
#           </li>
#           <li class="list">
#             <span class="list__index blue">3</span> Red Velvet (레드벨벳)
#           </li>
#           <li class="list">
#             <span class="list__index">4</span> IKON
#           </li>
#           <li class="list">
#             <span class="list__index">5</span> 멜로망스
#           </li>
#           <li class="list">
#             <span class="list__index">6</span> 다비치
#           </li>
#           <li class="list">
#             <span class="list__index">7</span> 윤딴딴
#           </li>
#           <li class="list">
#             <span class="list__index">8</span> 수지 (SUZY)
#           </li>
#           <li class="list">
#             <span class="list__index">9</span> 김동률
#           </li>
#           <li class="list">
#             <span class="list__index">10</span> 폴킴
#           </li>
#         </ul>
#       </article>
#       <article class="rank">
#         <h3 class="rank__title">검색어 순위</h3>
#         <ul class="rank__order">
#           <li class="list">
#             <span class="list__index blue">1</span> <b class="list__rating"><i class="dash"></i>0</b> Queen
#           </li>
#           <li class="list">
#             <span class="list__index blue">2</span> <b class="list__rating"><i class="dash"></i>0</b> 방탄소년단
#           </li>
#           <li class="list">
#             <span class="list__index blue">3</span> <b class="list__rating"><i class="dash"></i>0</b> 아이유
#           </li>
#           <li class="list">
#             <span class="list__index">4</span> <b class="list__rating"><img class="und" src="/images/music/up.png"
#                                                                             alt="up"/>7</b> 거미
#           </li>
#           <li class="list">
#             <span class="list__index">5</span> <b class="list__rating"><img class="und" src="/images/music/down.png"
#                                                                             alt="down"/>1</b> 폴킴
#           </li>
#           <li class="list">
#             <span class="list__index">6</span> <b class="list__rating"><img class="und" src="/images/music/up.png"
#                                                                             alt="up"/>1</b> 김범수
#           </li>
#           <li class="list">
#             <span class="list__index">7</span> <b class="list__rating"><img class="und" src="/images/music/up.png"
#                                                                             alt="up"/>6</b> 헤이즈
#           </li>
#           <li class="list">
#             <span class="list__index">8</span> <b class="list__rating"><img class="und" src="/images/music/down.png"
#                                                                             alt="down"/>2</b> 트와이스
#           </li>
#           <li class="list">
#             <span class="list__index">9</span> <b class="list__rating"><img class="und" src="/images/music/up.png"
#                                                                             alt="up"/>7</b> 박효신
#           </li>
#           <li class="list">
#             <span class="list__index">10</span> <b class="list__rating"><i class="dash"></i>0</b> 신용재
#           </li>
#         </ul>
#       </article>
#     </section>
#     <section id="list-container" class="main__listWrapper">
#       <article
#         class="playlist"
#         v-for="(item, index) in playlist"
#         v-bind:key="index"
#       >
#         <h5 class="playlist__theme">{{item.category}}</h5>
#         <img class="playlist__img" :src="item.imageUrl" alt="background"/>
#         <div class="playlist__meta">
#           <img class="owner" :src="item.authorProfileImageUrl" alt="owner"/>
#           <h3 class="title">{{item.title}}</h3>
#           <p class="tags">
#             <a class="tag" href="#"
#                v-for="(tag, index) in item.tags"
#                v-bind:key="index"
#             >#{{tag}} </a>
#           </p>
#           <div class="data">
#             <img class="data__like-img" src="/images/music/like.png" alt="like"/>
#             <span class="data__like-count">{{item.likeCount}}</span>
#             <img class="data__music-img" src="/images/music/music.png" alt="music"/>
#             <span class="data__music-count">{{item.trackCount}}</span>
#           </div>
#         </div>
#       </article>
#     </section>
#   </div>
# </div>
# <script src="/js/music.js"></script>
# </body>
# </html>

# %% [markdown]
# ### BeautifulSoup 타입으로 바꾸기
#
# 파싱을 위해 HTML 코드를 BeautifulSoup형식으로 바꿔주자

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://workey.codeit.kr/music/index")

soup = BeautifulSoup(response.text, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <script src="https://cdn.jsdelivr.net/npm/vue/dist/vue.js"></script>
# <script src="https://unpkg.com/axios/dist/axios.min.js"></script>
# <meta charset="utf-8"/>
# <title>Codeit Music</title>
# <style>
#     body {
#       margin: 0;
#     }
#
#     a {
#       text-decoration: none;
#       color: inherit;
#     }
#
#     img {
#       vertical-align: middle;
#     }
#
#     ul {
#       list-style: none;
#       padding: 0;
#       margin: 0;
#     }
#
#     * {
#       box-sizing: border-box;
#     }
#
#     .header {
#       position: fixed;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 60px;
#       background-color: #ffffff;
#       overflow: hidden;
#       z-index: 1;
#     }
#
#     .nav-warpper {
#       max-width: 1163px;
#       margin: 0 auto;
#       height: 100%;
#       line-height: 60px;
#       padding: 0 20px
#     }
#
#     .header__logo .logo-img {
#       width: 34px;
#       margin-right: 25px;
#     }
#
#     .header__nav {
#       display: inline-block;
#       vertical-align: middle;
#     }
#
#     .header__nav .menu {
#       float: left;
#       font-size: 16px;
#       color: #4a4a4a;
#       margin-right: 21px;
#     }
#
#     .header__search {
#       display: inline-block;
#       vertical-align: middle;
#       margin: 0 53px;
#       width: 397px;
#       height: 36px;
#       line-height: 36px;
#       border-radius: 22px;
#       border: 1px solid #4a90e2;
#       padding: 0 13px;
#     }
#
#     .header__search .icon {
#       width: 24px;
#       margin-right: 4px;
#     }
#
#     .header__search .input {
#       border: none;
#       outline: none;
#       font-size: 14px;
#       background: transparent;
#       width: calc(100% - 35px);
#     }
#
#     .header__user {
#       display: inline-block;
#       float: right;
#     }
#
#     .header__user .name {
#       font-size: 14px;
#       color: #4a4a4a;
#       margin-right: 14px;
#     }
#
#     .header__user .profile {
#       width: 30px;
#     }
#
#     .main {
#       min-height: calc(100vh - 60px);
#       padding-top: 60px;
#       background-color: #fafafa;
#       position: relative;
#       overflow: hidden;
#     }
#
#     .main section {
#       float: left;
#     }
#
#     .contents-warpper {
#       max-width: 991px;
#       margin: 0 auto;
#       padding: 34px 0;
#     }
#
#     .main__sidebar {
#       width: 231px;
#       margin-right: 23px;
#     }
#
#     .main__sidebar article {
#       width: 100%;
#       border-radius: 7px;
#       background-color: #ffffff;
#       padding: 17px 13px 5px;
#       margin-bottom: 32px;
#     }
#
#     .main__sidebar .popular__title,
#     .main__sidebar .rank__title {
#       margin: 0 0 24px;
#       font-size: 14px;
#       font-weight: bold;
#       color: #4a4a4a;
#     }
#
#     .main__sidebar .list {
#       font-size: 14px;
#       color: #4a4a4a;
#       margin-bottom: 12px;
#     }
#
#     .main__sidebar .list__index {
#       display: inline-block;
#       width: 18px;
#       height: 18px;
#       line-height: 1.8;
#       text-align: center;
#       font-size: 11px;
#       font-weight: bold;
#       border-radius: 6px;
#       color: #ffffff;
#       background-color: #dbdbdb;
#     }
#
#     .main__sidebar .list__index.blue {
#       background-color: #2391e9;
#     }
#
#     .main__sidebar .popular__order .list__index {
#       margin-right: 18px;
#     }
#
#     .main__sidebar .rank__order .list__index {
#       margin-right: 10px;
#     }
#
#     .main__sidebar .list__rating {
#       font-size: 14px;
#       font-weight: normal;
#       color: #9b9b9b;
#       text-align: center;
#       width: 25px;
#       display: inline-block;
#     }
#
#     .main__sidebar .und {
#       width: 8px;
#       vertical-align: unset;
#       margin-right: 2px;
#     }
#
#     .main__sidebar .dash {
#       display: inline-block;
#       width: 6px;
#       height: 1px;
#       background-color: #979797;
#       vertical-align: super;
#       margin-right: 3px;
#       margin-left: 1px;
#     }
#
#     .main__listWrapper {
#       width: 737px;
#     }
#
#     .main__listWrapper .playlist {
#       width: 100%;
#       height: 240px;
#       border-radius: 7px;
#       box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15);
#       position: relative;
#       overflow: hidden;
#       background-color: #ffffff;
#       margin-bottom: 34px;
#     }
#
#     .main__listWrapper .playlist__theme {
#       width: 68px;
#       border-bottom: 1px solid #ffffff;
#       position: absolute;
#       top: 23px;
#       left: 26px;
#       margin: 0;
#       color: #ffffff;
#       text-align: center;
#       padding-bottom: 8px;
#       font-size: 14px;
#       font-weight: bold;
#     }
#
#     .main__listWrapper .playlist__img {
#       width: 397px;
#       float: left;
#     }
#
#     .main__listWrapper .playlist__meta {
#       padding: 22px 19px;
#       float: left;
#       width: 340px;
#     }
#
#     .main__listWrapper .playlist__meta .owner {
#       width: 60px;
#       float: left;
#       margin-right: 15px;
#     }
#
#     .main__listWrapper .playlist__meta .title {
#       margin: 0;
#       font-size: 20px;
#       font-weight: normal;
#       color: #4a4a4a;
#       word-break: keep-all;
#       height: 48px;
#     }
#
#     .main__listWrapper .playlist__meta .tags {
#       margin: 45px 0 16px;
#       padding-bottom: 15px;
#       border-bottom: 1px solid #9b9b9b;
#       color: #9b9b9b;
#       font-size: 14px;
#       line-height: 1.7;
#     }
#
#     .main__listWrapper .playlist__meta .data img {
#       width: 20px;
#     }
#
#     .main__listWrapper .playlist__meta .data span {
#       vertical-align: middle;
#       margin-left: 6px;
#       margin-right: 16px;
#     }
#
#     @media (max-width: 991px) {
#       body * {
#         display: none;
#       }
#
#       body {
#         width: 100vw;
#         height: 100vh;
#         background-color: rgba(0, 0, 0, 0.8);
#       }
#
#       body::after {
#         display: block;
#         content: '지원하지 않는 화면 크기 입니다. 브라우저 크기를 넓혀주세요.';
#         position: absolute;
#         top: 50%;
#         left: 50%;
#         width: 230px;
#         word-break: keep-all;
#         text-align: center;
#         line-height: 1.7;
#         font-size: 18px;
#         color: #ffffff;
#         transform: translate(-50%, -50%);
#       }
#     }
#   </style>
# </head>
# <body>
# <header class="header">
# <nav class="nav-warpper">
# <a class="header__logo" href="#"><img alt="logo" class="logo-img" src="/images/music/logo.png"/></a>
# <ul class="header__nav">
# <li class="menu"><a href="#">인기차트</a></li>
# <li class="menu"><a href="#">추천음악</a></li>
# <li class="menu"><a href="#">뮤직비디오</a></li>
# </ul>
# <div class="header__search">
# <img class="icon" src="/images/music/search.png"/>
# <input class="input" placeholder="오늘은 무슨 음악을 들을까?" type="text"/>
# </div>
# <div class="header__user">
# <span class="name">강영훈</span>
# <img alt="user" class="profile" src="/images/music/user.png"/>
# </div>
# </nav>
# </header>
# <div class="main">
# <div class="contents-warpper">
# <section class="main__sidebar">
# <article class="popular">
# <h3 class="popular__title">인기 아티스트</h3>
# <ul class="popular__order">
# <li class="list">
# <span class="list__index blue">1</span> 아이유 (IU)
#           </li>
# <li class="list">
# <span class="list__index blue">2</span> 방탄소년단
#           </li>
# <li class="list">
# <span class="list__index blue">3</span> Red Velvet (레드벨벳)
#           </li>
# <li class="list">
# <span class="list__index">4</span> IKON
#           </li>
# <li class="list">
# <span class="list__index">5</span> 멜로망스
#           </li>
# <li class="list">
# <span class="list__index">6</span> 다비치
#           </li>
# <li class="list">
# <span class="list__index">7</span> 윤딴딴
#           </li>
# <li class="list">
# <span class="list__index">8</span> 수지 (SUZY)
#           </li>
# <li class="list">
# <span class="list__index">9</span> 김동률
#           </li>
# <li class="list">
# <span class="list__index">10</span> 폴킴
#           </li>
# </ul>
# </article>
# <article class="rank">
# <h3 class="rank__title">검색어 순위</h3>
# <ul class="rank__order">
# <li class="list">
# <span class="list__index blue">1</span> <b class="list__rating"><i class="dash"></i>0</b> Queen
#           </li>
# <li class="list">
# <span class="list__index blue">2</span> <b class="list__rating"><i class="dash"></i>0</b> 방탄소년단
#           </li>
# <li class="list">
# <span class="list__index blue">3</span> <b class="list__rating"><i class="dash"></i>0</b> 아이유
#           </li>
# <li class="list">
# <span class="list__index">4</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>7</b> 거미
#           </li>
# <li class="list">
# <span class="list__index">5</span> <b class="list__rating"><img alt="down" class="und" src="/images/music/down.png"/>1</b> 폴킴
#           </li>
# <li class="list">
# <span class="list__index">6</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>1</b> 김범수
#           </li>
# <li class="list">
# <span class="list__index">7</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>6</b> 헤이즈
#           </li>
# <li class="list">
# <span class="list__index">8</span> <b class="list__rating"><img alt="down" class="und" src="/images/music/down.png"/>2</b> 트와이스
#           </li>
# <li class="list">
# <span class="list__index">9</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>7</b> 박효신
#           </li>
# <li class="list">
# <span class="list__index">10</span> <b class="list__rating"><i class="dash"></i>0</b> 신용재
#           </li>
# </ul>
# </article>
# </section>
# <section class="main__listWrapper" id="list-container">
# <article class="playlist" v-bind:key="index" v-for="(item, index) in playlist">
# <h5 class="playlist__theme">{{item.category}}</h5>
# <img :src="item.imageUrl" alt="background" class="playlist__img"/>
# <div class="playlist__meta">
# <img :src="item.authorProfileImageUrl" alt="owner" class="owner"/>
# <h3 class="title">{{item.title}}</h3>
# <p class="tags">
# <a class="tag" href="#" v-bind:key="index" v-for="(tag, index) in item.tags">#{{tag}} </a>
# </p>
# <div class="data">
# <img alt="like" class="data__like-img" src="/images/music/like.png"/>
# <span class="data__like-count">{{item.likeCount}}</span>
# <img alt="music" class="data__music-img" src="/images/music/music.png"/>
# <span class="data__music-count">{{item.trackCount}}</span>
# </div>
# </div>
# </article>
# </section>
# </div>
# </div>
# <script src="/js/music.js"></script>
# </body>
# </html>

# %% [markdown]
# ### 태그 골라내기
#
# 위 HTML태그에서 10명의 인기차트 아티스트 이름을 선택해보자
#
# ``'poppular__order'``클래스를 가진 ``<ul>``태그에 중첩된 모든 ``<li>``태그를 선택.
# 선택자를 ``.popular__order li``라고 하면 될 것

# %%
soup.select('.popular__order li')
# Out:
# [<li class="list">
#  <span class="list__index blue">1</span> 아이유 (IU)
#            </li>, <li class="list">
#  <span class="list__index blue">2</span> 방탄소년단
#            </li>, <li class="list">
#  <span class="list__index blue">3</span> Red Velvet (레드벨벳)
#            </li>, <li class="list">
#  <span class="list__index">4</span> IKON
#            </li>, <li class="list">
#  <span class="list__index">5</span> 멜로망스
#            </li>, <li class="list">
#  <span class="list__index">6</span> 다비치
#            </li>, <li class="list">
#  <span class="list__index">7</span> 윤딴딴
#            </li>, <li class="list">
#  <span class="list__index">8</span> 수지 (SUZY)
#            </li>, <li class="list">
#  <span class="list__index">9</span> 김동률
#            </li>, <li class="list">
#  <span class="list__index">10</span> 폴킴
#            </li>]

# %% [markdown]
# 이 중에서 아티스트명 텍스트만 추출해보자

# %%
li_tags = soup.select('.popular__order li')

popular_artist = []

\
for pop in li_tags:
    popular_artist.append(pop.text)
    
print(popular_artist)
# Out:
# ['\n1 아이유 (IU)\n          ', '\n2 방탄소년단\n          ', '\n3 Red Velvet (레드벨벳)\n          ', '\n4 IKON\n          ', '\n5 멜로망스\n          ', '\n6 다비치\n          ', '\n7 윤딴딴\n          ', '\n8 수지 (SUZY)\n          ', '\n9 김동률\n          ', '\n10 폴킴\n          ']

# %% [markdown]
# 앞뒤 공백이 존재하지 이를 제거해보자

# %%
li_tags = soup.select('.popular__order li')

popular_artist = []

for pop in li_tags:
    popular_artist.append(pop.text.strip())
    
print(popular_artist)
# Out:
# ['1 아이유 (IU)', '2 방탄소년단', '3 Red Velvet (레드벨벳)', '4 IKON', '5 멜로망스', '6 다비치', '7 윤딴딴', '8 수지 (SUZY)', '9 김동률', '10 폴킴']

# %% [markdown]
# ## 그녀의 전화번호를 찾아서
#
# 운명적인 그녀를 만났지만 그녀가 오렌지 보틀에서 일한다는 것 말고는 아는 사실이 없다.
#
# 오렌지 보틀의 웹사이트에서 모든 지점의 전화번호를 모아보려 한다.

# %%
import requests

from bs4 import BeautifulSoup

response = requests.get('https://workey.codeit.kr/orangebottle/index')

soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Orange bottle coffee</title>
# <meta charset="utf-8"/>
# <link href="https://fonts.googleapis.com/css?family=Noto+Sans+KR" rel="stylesheet"/>
# <style>
#         body {
#             font-family: 'Noto Sans KR', sans-serif;
#             margin: 0;
#             background-color: #ffffff;
#         }
#
#         /*navigation bar*/
#         #bottle {
#             margin-top: 12px;
#             margin-bottom: 11px;
#             margin-left: 79px;
#             margin-right: 24px;
#             vertical-align: middle;
#             width: 13px;
#         }
#
#         #title {
#             font-size: 14px;
#             font-weight: bold;
#             vertical-align: middle;
#             color: #4a4a4a;
#         }
#
#         ul {
#             display: inline;
#             padding-left: 0;
#         }
#
#         li {
#             float: right;
#             list-style-type: none;
#             font-size: 14px;
#         }
#
#         #subscribe {
#             color: #f5a623;
#             margin-right: 25px;
#             line-height: 58px;
#         }
#
#         #signin {
#             margin-right: 65px;
#             line-height: 58px;
#             color: #4a4a4a;
#         }
#
#         /*main image*/
#         #mainimg {
#             height: 533px;
#             line-height: 533px;
#             margin-bottom: 122px;
#             background-image: url("/images/orangebottle/background.jpg");
#             background-size: cover;
#             background-position: center center;
#             text-align: center;
#         }
#
#         #mainimg #maintext {
#             line-height: normal;
#             display: inline-block;
#             vertical-align: middle;
#             font-size: 25px;
#             color: #ffffff;
#         }
#
#         /*branches*/
#         .container {
#             width: 1100px;
#             margin-left: auto;
#             margin-right: auto;
#             overflow: hidden;
#         }
#
#         .container .branch {
#             width: 25%;
#             height: 164px;
#             float: left;
#             padding-left: 40px;
#             padding-right: 40px;
#             margin-top: 10px;
#             margin-bottom: 80px;
#             box-sizing: border-box;
#         }
#
#         .container .branch .city {
#             display: inline-block;
#             margin: 0;
#             border-radius: 8px;
#             padding: 5px 8px;
#             font-size: 14px;
#             color: white;
#             background-color: #f5a623;
#         }
#
#         .container .branch .ave {
#             margin: 12px 0;
#             font-size: 16px;
#             color: #f5a623;
#         }
#
#         .container .branch .address {
#             margin: 12px 0;
#             color: #4a4a4a;
#             line-height: 1.6;
#         }
#
#         .container .branch img {
#             vertical-align: middle;
#             margin-right: 9px;
#         }
#
#         .container .branch .phoneNum {
#             color: #818181;
#         }
#
#         /*signup*/
#
#         #footer {
#             width: 100%;
#             height: 453px;
#             background-color: #f9f9f9;
#             float: left;
#         }
#
#         #footer h1 {
#             margin-top: 75px;
#             margin-bottom: 37px;
#             font-size: 40px;
#             font-weight: 300;
#             text-align: center;
#             color: #9b9b9b;
#         }
#
#         #footer h2 {
#             font-size: 16px;
#             text-align: center;
#             color: #4a4a4a;
#             margin-bottom: 58px;
#         }
#
#         #footer #signup {
#             width: 646px;
#             height: 70px;
#             background-color: white;
#             margin-left: auto;
#             margin-right: auto;
#         }
#
#         #footer #signup input {
#             border: none;
#             font-size: 20px; /*원래는 16*/
#             margin-top: 19px;
#             margin-bottom: 27px;
#             margin-left: 34px;
#             color: #9b9b9b;
#             width: 450px;
#             height: 30px;
#         }
#
#         #footer #signup #submit {
#             width: 130px;
#             height: 70px;
#             float: right;
#             background-color: #f5a623;
#             text-align: center;
#             line-height: 70px;
#         }
#
#         #footer #signup a {
#             text-decoration: none;
#             color: #ffffff;
#             font-size: 18px;
#         }
#
#
#     </style>
# </head>
# <body>
# <div id="navbar">
# <a href="#" style="text-decoration: none;color:#4a4a4a;">
# <img id="bottle" src="/images/orangebottle/logo.png"/>
# <span id="title"> ORANGE BOTTLE COFFEE</span>
# </a>
# <ul>
# <a href="#" style="color:black;">
# <li id="signin">SIGN IN</li>
# </a>
# <a href="#">
# <li id="subscribe">SUBSCRIBE</li>
# </a>
# </ul>
# </div>
# <!-- main image -->
# <div id="mainimg">
# <div id="maintext">
# <h1>Find Your Orange Bottle Cafe</h1>
# </div>
# </div>
# <!-- cafe branches -->
# <div class="container">
# <div class="branch">
# <p class="city">San Jose</p>
# <p class="ave">Fairway</p>
# <p class="address">4823 Fairway Drive</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">707-514-0033</span>
# </div>
# <div class="branch">
# <p class="city">GREAT BARTON</p>
# <p class="ave">Lammas</p>
# <p class="address">106 Lammas Street</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">070 3460 5076</span>
# </div>
# <div class="branch">
# <p class="city">Hamilton</p>
# <p class="ave">Bridgeport</p>
# <p class="address">3791  Bridgeport Rd</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">905-389-4463</span>
# </div>
# <div class="branch">
# <p class="city">JERRAWA</p>
# <p class="ave">Marlin</p>
# <p class="address">40 Marlin Avenue</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">(02) 6175 8642</span>
# </div>
# <div class="branch">
# <p class="city">Rudersberg</p>
# <p class="ave">Pasewalker</p>
# <p class="address">Pasewalker Straße 5</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">07183 30 07 96</span>
# </div>
# <div class="branch">
# <p class="city">København K</p>
# <p class="ave">Toftvej</p>
# <p class="address">Toftvej 35</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">21-90-47700</span>
# </div>
# <div class="branch">
# <p class="city">Guadalajara</p>
# <p class="ave">Revolucion</p>
# <p class="address">Av. Revolucion 737</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">33 36175334</span>
# </div>
# <div class="branch">
# <p class="city">Poughkeepsie</p>
# <p class="ave">Old Dear Lane</p>
# <p class="address">4927 Old Dear Lane</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">845-857-0825</span>
# </div>
# <div class="branch">
# <p class="city">Elgin</p>
# <p class="ave">Pineview</p>
# <p class="address">2491 Pineview Drive</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">507-876-0713</span>
# </div>
# <div class="branch">
# <p class="city">Oak Brook</p>
# <p class="ave">Vesta</p>
# <p class="address">2591 Vesta Drive</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">773-757-1932</span>
# </div>
# <div class="branch">
# <p class="city">Annapolis Junction</p>
# <p class="ave">Bluff</p>
# <p class="address">889 Bluff Street</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">301-787-8206</span>
# </div>
# <div class="branch">
# <p class="city">Los Angeles</p>
# <p class="ave">Jett</p>
# <p class="address">1014 Jett Lane</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">310-718-6212</span>
# </div>
# <div class="branch">
# <p class="city">Arlington</p>
# <p class="ave">Single</p>
# <p class="address">3158 Single Street</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">781-646-1715</span>
# </div>
# <div class="branch">
# <p class="city">Syracuse</p>
# <p class="ave">Plainfield</p>
# <p class="address">3741 Plainfield Avenue</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">315-576-8242</span>
# </div>
# <div class="branch">
# <p class="city">San Mateo</p>
# <p class="ave">Thunder</p>
# <p class="address">2425 Thunder Road</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">650-577-7537</span>
# </div>
# <div class="branch">
# <p class="city">Valdosta</p>
# <p class="ave">Junkins</p>
# <p class="address">1022 Junkins Avenue</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">229-460-4970</span>
# </div>
# <div class="branch">
# <p class="city">Hialeah</p>
# <p class="ave">Poplar</p>
# <p class="address">101 Poplar Lane</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">305-540-4990</span>
# </div>
# <div class="branch">
# <p class="city">Lexington</p>
# <p class="ave">Straford</p>
# <p class="address">793 Straford Park</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">606-614-9190</span>
# </div>
# <div class="branch">
# <p class="city">Johnsonburg</p>
# <p class="ave">Custer</p>
# <p class="address">2566 Custer Street</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">814-965-6502</span>
# </div>
# <div class="branch">
# <p class="city">Hokkaido</p>
# <p class="ave">Kita</p>
# <p class="address">244-1192, Kita 6-jonishi, Abashiri-shi, Hokkaido</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">8134-191-6900</span>
# </div>
# <div class="branch">
# <p class="city">Port Chester</p>
# <p class="ave">Ward</p>
# <p class="address">1503 Ward Road</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">914-933-3946</span>
# </div>
# <div class="branch">
# <p class="city">Salt Lake City</p>
# <p class="ave">Kemper</p>
# <p class="address">4745 Kemper Lane</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">801-927-7191</span>
# </div>
# <div class="branch">
# <p class="city">Villaluenga del Rosario</p>
# <p class="ave">Vientos</p>
# <p class="address">C/ Rosa de los Vientos 36</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">736 301 706</span>
# </div>
# <div class="branch">
# <p class="city">London</p>
# <p class="ave">King Street</p>
# <p class="address">733 King Street EAST CENTRAL LONDON EC86 0YR</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">916-863-6154</span>
# </div>
# <div class="branch">
# <p class="city">GLOUCESTER</p>
# <p class="ave">New Road</p>
# <p class="address">8857 New Road GLOUCESTER GL79 3CZ</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">252-218-2526</span>
# </div>
# <div class="branch">
# <p class="city">NEWPORT</p>
# <p class="ave">George</p>
# <p class="address">760 George Street NEWPORT NP73 0CH</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">803-535-5627</span>
# </div>
# <div class="branch">
# <p class="city">TAUNTON</p>
# <p class="ave">The Green</p>
# <p class="address">749 The Green TAUNTON TA27 9JQ</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">580-730-2253</span>
# </div>
# <div class="branch">
# <p class="city">SOUTHEND-ON-SEA</p>
# <p class="ave">Springfield</p>
# <p class="address">271 Springfield Road SOUTHEND-ON-SEA SS98 1PA</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">240-597-0099</span>
# </div>
# <div class="branch">
# <p class="city">SHEFFIELD</p>
# <p class="ave">Highfield</p>
# <p class="address">500 Highfield Road SHEFFIELD S98 6VM</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">210-727-9560</span>
# </div>
# <div class="branch">
# <p class="city">HULL</p>
# <p class="ave">Albert</p>
# <p class="address">8772 Albert Road HULL HU2 6SN</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">919-887-6912</span>
# </div>
# <div class="branch">
# <p class="city">SHREWSBURY</p>
# <p class="ave">Church</p>
# <p class="address">38 Church Street SHREWSBURY SY79 9TY</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">614-449-8617</span>
# </div>
# <div class="branch">
# <p class="city">DURHAM</p>
# <p class="ave">DURHAM</p>
# <p class="address">12 New Road DURHAM DH78 4XK</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">830-229-4983</span>
# </div>
# <div class="branch">
# <p class="city">Honolulu</p>
# <p class="ave">Don Jackson</p>
# <p class="address">4153 Don Jackson Lane</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">303-284-0638</span>
# </div>
# <div class="branch">
# <p class="city">Wayne</p>
# <p class="ave">Bombardier</p>
# <p class="address">2438 Bombardier Way</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">734-981-4470</span>
# </div>
# <div class="branch">
# <p class="city">Milton</p>
# <p class="ave">Courtright</p>
# <p class="address">3258 Courtright Street</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">701-496-3125</span>
# </div>
# <div class="branch">
# <p class="city">NEWCASTLE</p>
# <p class="ave">The Grove</p>
# <p class="address">9982 The Grove NEWCASTLE UPON TYNE NE21 0RM</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">605-677-5038</span>
# </div>
# <div class="branch">
# <p class="city">BRISTOL</p>
# <p class="ave">Richmond</p>
# <p class="address">8253 Richmond Road BRISTOL BS70 9LU</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">209-848-9572</span>
# </div>
# <div class="branch">
# <p class="city">BOURNEMOUTH</p>
# <p class="ave">Broadway</p>
# <p class="address">22 Broadway BOURNEMOUTH BH73 8ON</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">760-464-6831</span>
# </div>
# <div class="branch">
# <p class="city">LEICESTER</p>
# <p class="ave">Green Lane</p>
# <p class="address">748 Green Lane LEICESTER LE77 6VE</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">508-272-0114</span>
# </div>
# <div class="branch">
# <p class="city">SUNDERLAND</p>
# <p class="ave">New Road</p>
# <p class="address">48 New Road SUNDERLAND SR39 2NY</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">845-915-5076</span>
# </div>
# <div class="branch">
# <p class="city">BOLTON</p>
# <p class="ave">North Street</p>
# <p class="address">19 North Street BOLTON BL77 4TC</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">973-640-3581</span>
# </div>
# <div class="branch">
# <p class="city">SOUTHAMPTON</p>
# <p class="ave">King Street</p>
# <p class="address">60 King Street SOUTHAMPTON SO75 5PZ</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">541-579-1559</span>
# </div>
# <div class="branch">
# <p class="city">BLACKPOOL</p>
# <p class="ave">Highfield</p>
# <p class="address">8579 Highfield Road BLACKPOOL FY68 1LM</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">336-212-0408</span>
# </div>
# <div class="branch">
# <p class="city">DARLINGTON</p>
# <p class="ave">High Street</p>
# <p class="address">9175 High Street DARLINGTON DL86 7BQ</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">845-340-3808</span>
# </div>
# <div class="branch">
# <p class="city">LIVERPOOL</p>
# <p class="ave">Main Road</p>
# <p class="address">100 Main Road LIVERPOOL L80 4XI</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">561-526-2625</span>
# </div>
# <div class="branch">
# <p class="city">MANCHESTER</p>
# <p class="ave">Park Lane</p>
# <p class="address">52 Park Lane MANCHESTER M8 0KJ</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">801-608-1332</span>
# </div>
# <div class="branch">
# <p class="city">SHEFFIELD</p>
# <p class="ave">Kings Road</p>
# <p class="address">79 Kings Road SHEFFIELD S88 2KY</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">510-214-0266</span>
# </div>
# <div class="branch">
# <p class="city">BOLTON</p>
# <p class="ave">Mill</p>
# <p class="address">95 Mill Road BOLTON BL48 9OR</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">785-253-0084</span>
# </div>
# <div class="branch">
# <p class="city">SWANSEA</p>
# <p class="ave">South</p>
# <p class="address">466 South Street SWANSEA SA34 7PT</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">585-749-2163</span>
# </div>
# <div class="branch">
# <p class="city">LEEDS</p>
# <p class="ave">Mill Lane</p>
# <p class="address">308 Mill Lane LEEDS LS35 5JS</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">312-362-2484</span>
# </div>
# <div class="branch">
# <p class="city">SWANSEA</p>
# <p class="ave">York Road</p>
# <p class="address">222 York Road SWANSEA SA87 4WS</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">570-603-5788</span>
# </div>
# <div class="branch">
# <p class="city">CARDIFF</p>
# <p class="ave">West Street</p>
# <p class="address">125 West Street CARDIFF CF95 6CN</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">802-738-8477</span>
# </div>
# <div class="branch">
# <p class="city">LEICESTER</p>
# <p class="ave">New Road</p>
# <p class="address">64 New Road LEICESTER LE37 3VW</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">507-771-8684</span>
# </div>
# <div class="branch">
# <p class="city">SOUTHAMPTON</p>
# <p class="ave">Main Street</p>
# <p class="address">90 Main Street SOUTHAMPTON SO41 5RP</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">720-634-0176</span>
# </div>
# <div class="branch">
# <p class="city">IPSWICH</p>
# <p class="ave">Stanley Road</p>
# <p class="address">8339 Stanley Road IPSWICH IP79 6SN</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">313-930-0331</span>
# </div>
# <div class="branch">
# <p class="city">Tokyo</p>
# <p class="ave">Ebisu</p>
# <p class="address">481-1228, Ebisu Ebisugadempureisu(28-kai), Shibuya-ku</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">8188-165-7118</span>
# </div>
# <div class="branch">
# <p class="city">Seoul</p>
# <p class="ave">Gongdeok</p>
# <p class="address">310-5, Samseongraemiangongdeok 3 chaapateu, Gongdeok-dong, Mapo-gu</p>
# <img src="/images/orangebottle/phone_icon.png" width="20px"/>
# <span class="phoneNum">02-455-1973</span>
# </div>
# </div>
# <!-- signup -->
# <div id="footer">
# <h1>SIGN UP</h1>
# <h2>Sign up for stories, coffee tips, and brewing equipment</h2>
# <div id="signup">
# <input placeholder="Your email here" type="text"/>
# <a href="#" id="submit">SIGN UP
#         </a>
# </div>
# </div>
# </body>
# </html>

# %%
class_tags = soup.select('.container .branch .phoneNum')

nums = []

for num in class_tags:
    nums.append(num.text)
    
print(nums)
# Out:
# ['707-514-0033', '070 3460 5076', '905-389-4463', '(02) 6175 8642', '07183 30 07 96', '21-90-47700', '33 36175334', '845-857-0825', '507-876-0713', '773-757-1932', '301-787-8206', '310-718-6212', '781-646-1715', '315-576-8242', '650-577-7537', '229-460-4970', '305-540-4990', '606-614-9190', '814-965-6502', '8134-191-6900', '914-933-3946', '801-927-7191', '736 301 706', '916-863-6154', '252-218-2526', '803-535-5627', '580-730-2253', '240-597-0099', '210-727-9560', '919-887-6912', '614-449-8617', '830-229-4983', '303-284-0638', '734-981-4470', '701-496-3125', '605-677-5038', '209-848-9572', '760-464-6831', '508-272-0114', '845-915-5076', '973-640-3581', '541-579-1559', '336-212-0408', '845-340-3808', '561-526-2625', '801-608-1332', '510-214-0266', '785-253-0084', '585-749-2163', '312-362-2484', '570-603-5788', '802-738-8477', '507-771-8684', '720-634-0176', '313-930-0331', '8188-165-7118', '02-455-1973']

# %% [markdown]
# ## 검색어 순위 받아오기
#
# 음악사이트의 검색어 순위를 받아오려 합니다.
#
# '인기 아티스트' 아래에 있는 '검색어 순위'의 1위 ~ 10위 데이터를 파싱해서 리스트에 담아 print 해보세요

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://workey.codeit.kr/music/index')

soup = BeautifulSoup(response.text, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <script src="https://cdn.jsdelivr.net/npm/vue/dist/vue.js"></script>
# <script src="https://unpkg.com/axios/dist/axios.min.js"></script>
# <meta charset="utf-8"/>
# <title>Codeit Music</title>
# <style>
#     body {
#       margin: 0;
#     }
#
#     a {
#       text-decoration: none;
#       color: inherit;
#     }
#
#     img {
#       vertical-align: middle;
#     }
#
#     ul {
#       list-style: none;
#       padding: 0;
#       margin: 0;
#     }
#
#     * {
#       box-sizing: border-box;
#     }
#
#     .header {
#       position: fixed;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 60px;
#       background-color: #ffffff;
#       overflow: hidden;
#       z-index: 1;
#     }
#
#     .nav-warpper {
#       max-width: 1163px;
#       margin: 0 auto;
#       height: 100%;
#       line-height: 60px;
#       padding: 0 20px
#     }
#
#     .header__logo .logo-img {
#       width: 34px;
#       margin-right: 25px;
#     }
#
#     .header__nav {
#       display: inline-block;
#       vertical-align: middle;
#     }
#
#     .header__nav .menu {
#       float: left;
#       font-size: 16px;
#       color: #4a4a4a;
#       margin-right: 21px;
#     }
#
#     .header__search {
#       display: inline-block;
#       vertical-align: middle;
#       margin: 0 53px;
#       width: 397px;
#       height: 36px;
#       line-height: 36px;
#       border-radius: 22px;
#       border: 1px solid #4a90e2;
#       padding: 0 13px;
#     }
#
#     .header__search .icon {
#       width: 24px;
#       margin-right: 4px;
#     }
#
#     .header__search .input {
#       border: none;
#       outline: none;
#       font-size: 14px;
#       background: transparent;
#       width: calc(100% - 35px);
#     }
#
#     .header__user {
#       display: inline-block;
#       float: right;
#     }
#
#     .header__user .name {
#       font-size: 14px;
#       color: #4a4a4a;
#       margin-right: 14px;
#     }
#
#     .header__user .profile {
#       width: 30px;
#     }
#
#     .main {
#       min-height: calc(100vh - 60px);
#       padding-top: 60px;
#       background-color: #fafafa;
#       position: relative;
#       overflow: hidden;
#     }
#
#     .main section {
#       float: left;
#     }
#
#     .contents-warpper {
#       max-width: 991px;
#       margin: 0 auto;
#       padding: 34px 0;
#     }
#
#     .main__sidebar {
#       width: 231px;
#       margin-right: 23px;
#     }
#
#     .main__sidebar article {
#       width: 100%;
#       border-radius: 7px;
#       background-color: #ffffff;
#       padding: 17px 13px 5px;
#       margin-bottom: 32px;
#     }
#
#     .main__sidebar .popular__title,
#     .main__sidebar .rank__title {
#       margin: 0 0 24px;
#       font-size: 14px;
#       font-weight: bold;
#       color: #4a4a4a;
#     }
#
#     .main__sidebar .list {
#       font-size: 14px;
#       color: #4a4a4a;
#       margin-bottom: 12px;
#     }
#
#     .main__sidebar .list__index {
#       display: inline-block;
#       width: 18px;
#       height: 18px;
#       line-height: 1.8;
#       text-align: center;
#       font-size: 11px;
#       font-weight: bold;
#       border-radius: 6px;
#       color: #ffffff;
#       background-color: #dbdbdb;
#     }
#
#     .main__sidebar .list__index.blue {
#       background-color: #2391e9;
#     }
#
#     .main__sidebar .popular__order .list__index {
#       margin-right: 18px;
#     }
#
#     .main__sidebar .rank__order .list__index {
#       margin-right: 10px;
#     }
#
#     .main__sidebar .list__rating {
#       font-size: 14px;
#       font-weight: normal;
#       color: #9b9b9b;
#       text-align: center;
#       width: 25px;
#       display: inline-block;
#     }
#
#     .main__sidebar .und {
#       width: 8px;
#       vertical-align: unset;
#       margin-right: 2px;
#     }
#
#     .main__sidebar .dash {
#       display: inline-block;
#       width: 6px;
#       height: 1px;
#       background-color: #979797;
#       vertical-align: super;
#       margin-right: 3px;
#       margin-left: 1px;
#     }
#
#     .main__listWrapper {
#       width: 737px;
#     }
#
#     .main__listWrapper .playlist {
#       width: 100%;
#       height: 240px;
#       border-radius: 7px;
#       box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15);
#       position: relative;
#       overflow: hidden;
#       background-color: #ffffff;
#       margin-bottom: 34px;
#     }
#
#     .main__listWrapper .playlist__theme {
#       width: 68px;
#       border-bottom: 1px solid #ffffff;
#       position: absolute;
#       top: 23px;
#       left: 26px;
#       margin: 0;
#       color: #ffffff;
#       text-align: center;
#       padding-bottom: 8px;
#       font-size: 14px;
#       font-weight: bold;
#     }
#
#     .main__listWrapper .playlist__img {
#       width: 397px;
#       float: left;
#     }
#
#     .main__listWrapper .playlist__meta {
#       padding: 22px 19px;
#       float: left;
#       width: 340px;
#     }
#
#     .main__listWrapper .playlist__meta .owner {
#       width: 60px;
#       float: left;
#       margin-right: 15px;
#     }
#
#     .main__listWrapper .playlist__meta .title {
#       margin: 0;
#       font-size: 20px;
#       font-weight: normal;
#       color: #4a4a4a;
#       word-break: keep-all;
#       height: 48px;
#     }
#
#     .main__listWrapper .playlist__meta .tags {
#       margin: 45px 0 16px;
#       padding-bottom: 15px;
#       border-bottom: 1px solid #9b9b9b;
#       color: #9b9b9b;
#       font-size: 14px;
#       line-height: 1.7;
#     }
#
#     .main__listWrapper .playlist__meta .data img {
#       width: 20px;
#     }
#
#     .main__listWrapper .playlist__meta .data span {
#       vertical-align: middle;
#       margin-left: 6px;
#       margin-right: 16px;
#     }
#
#     @media (max-width: 991px) {
#       body * {
#         display: none;
#       }
#
#       body {
#         width: 100vw;
#         height: 100vh;
#         background-color: rgba(0, 0, 0, 0.8);
#       }
#
#       body::after {
#         display: block;
#         content: '지원하지 않는 화면 크기 입니다. 브라우저 크기를 넓혀주세요.';
#         position: absolute;
#         top: 50%;
#         left: 50%;
#         width: 230px;
#         word-break: keep-all;
#         text-align: center;
#         line-height: 1.7;
#         font-size: 18px;
#         color: #ffffff;
#         transform: translate(-50%, -50%);
#       }
#     }
#   </style>
# </head>
# <body>
# <header class="header">
# <nav class="nav-warpper">
# <a class="header__logo" href="#"><img alt="logo" class="logo-img" src="/images/music/logo.png"/></a>
# <ul class="header__nav">
# <li class="menu"><a href="#">인기차트</a></li>
# <li class="menu"><a href="#">추천음악</a></li>
# <li class="menu"><a href="#">뮤직비디오</a></li>
# </ul>
# <div class="header__search">
# <img class="icon" src="/images/music/search.png"/>
# <input class="input" placeholder="오늘은 무슨 음악을 들을까?" type="text"/>
# </div>
# <div class="header__user">
# <span class="name">강영훈</span>
# <img alt="user" class="profile" src="/images/music/user.png"/>
# </div>
# </nav>
# </header>
# <div class="main">
# <div class="contents-warpper">
# <section class="main__sidebar">
# <article class="popular">
# <h3 class="popular__title">인기 아티스트</h3>
# <ul class="popular__order">
# <li class="list">
# <span class="list__index blue">1</span> 아이유 (IU)
#           </li>
# <li class="list">
# <span class="list__index blue">2</span> 방탄소년단
#           </li>
# <li class="list">
# <span class="list__index blue">3</span> Red Velvet (레드벨벳)
#           </li>
# <li class="list">
# <span class="list__index">4</span> IKON
#           </li>
# <li class="list">
# <span class="list__index">5</span> 멜로망스
#           </li>
# <li class="list">
# <span class="list__index">6</span> 다비치
#           </li>
# <li class="list">
# <span class="list__index">7</span> 윤딴딴
#           </li>
# <li class="list">
# <span class="list__index">8</span> 수지 (SUZY)
#           </li>
# <li class="list">
# <span class="list__index">9</span> 김동률
#           </li>
# <li class="list">
# <span class="list__index">10</span> 폴킴
#           </li>
# </ul>
# </article>
# <article class="rank">
# <h3 class="rank__title">검색어 순위</h3>
# <ul class="rank__order">
# <li class="list">
# <span class="list__index blue">1</span> <b class="list__rating"><i class="dash"></i>0</b> Queen
#           </li>
# <li class="list">
# <span class="list__index blue">2</span> <b class="list__rating"><i class="dash"></i>0</b> 방탄소년단
#           </li>
# <li class="list">
# <span class="list__index blue">3</span> <b class="list__rating"><i class="dash"></i>0</b> 아이유
#           </li>
# <li class="list">
# <span class="list__index">4</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>7</b> 거미
#           </li>
# <li class="list">
# <span class="list__index">5</span> <b class="list__rating"><img alt="down" class="und" src="/images/music/down.png"/>1</b> 폴킴
#           </li>
# <li class="list">
# <span class="list__index">6</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>1</b> 김범수
#           </li>
# <li class="list">
# <span class="list__index">7</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>6</b> 헤이즈
#           </li>
# <li class="list">
# <span class="list__index">8</span> <b class="list__rating"><img alt="down" class="und" src="/images/music/down.png"/>2</b> 트와이스
#           </li>
# <li class="list">
# <span class="list__index">9</span> <b class="list__rating"><img alt="up" class="und" src="/images/music/up.png"/>7</b> 박효신
#           </li>
# <li class="list">
# <span class="list__index">10</span> <b class="list__rating"><i class="dash"></i>0</b> 신용재
#           </li>
# </ul>
# </article>
# </section>
# <section class="main__listWrapper" id="list-container">
# <article class="playlist" v-bind:key="index" v-for="(item, index) in playlist">
# <h5 class="playlist__theme">{{item.category}}</h5>
# <img :src="item.imageUrl" alt="background" class="playlist__img"/>
# <div class="playlist__meta">
# <img :src="item.authorProfileImageUrl" alt="owner" class="owner"/>
# <h3 class="title">{{item.title}}</h3>
# <p class="tags">
# <a class="tag" href="#" v-bind:key="index" v-for="(tag, index) in item.tags">#{{tag}} </a>
# </p>
# <div class="data">
# <img alt="like" class="data__like-img" src="/images/music/like.png"/>
# <span class="data__like-count">{{item.likeCount}}</span>
# <img alt="music" class="data__music-img" src="/images/music/music.png"/>
# <span class="data__music-count">{{item.trackCount}}</span>
# </div>
# </div>
# </article>
# </section>
# </div>
# </div>
# <script src="/js/music.js"></script>
# </body>
# </html>

# %%
soup.select('.list')[0].text
# Out:
# '\n1 아이유 (IU)\n          '

# %%
top_tags = soup.select('.rank .list')

ranking = []

for num in top_tags:
    ranking.append(num.text.strip().split(' '))
    
print(ranking)
# Out:
# [['1', '0', 'Queen'], ['2', '0', '방탄소년단'], ['3', '0', '아이유'], ['4', '7', '거미'], ['5', '1', '폴킴'], ['6', '1', '김범수'], ['7', '6', '헤이즈'], ['8', '2', '트와이스'], ['9', '7', '박효신'], ['10', '0', '신용재']]

# %% [markdown]
# 리스트의 리스트를 인덱싱 할 줄 몰라.... 데이터 프레임으로 전환 후 해당 열을 리스트로 다시 전환하는 방법을 사용하였다.

# %%
import pandas as pd

df_rank = pd.DataFrame(ranking)
search_ranks = list(df_rank[2])
print(search_ranks)
# Out:
# ['Queen', '방탄소년단', '아이유', '거미', '폴킴', '김범수', '헤이즈', '트와이스', '박효신', '신용재']

# %% [markdown]
# ### 해설 - 검색어 순위 받아오기

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://workey.codeit.kr/music/index')

soup = BeautifulSoup(response.text, 'html.parser')

top_tags = soup.select('.rank .list')

ranking = []

for num in top_tags:
    ranking.append(num.text.strip().split(' ')[2])   # 이렇게 인덱싱하면 되는걸.....
    
print(ranking)
# Out:
# ['Queen', '방탄소년단', '아이유', '거미', '폴킴', '김범수', '헤이즈', '트와이스', '박효신', '신용재']

# %% [markdown]
# ## 필요한 페이지만 가져오기
#
# 만약 이케아에서 'desk'를 검색하면 총 몇개의 검색 결과 페이지가 나올까?
#
# 예상할 수 없을 것
# 파싱을 활용하면 이케아에서 desk 정보가 아무리 많아도 수집할 수 있다.
#
# ### 방법1: 파싱으로 페이지 개수 알아내기
#
# 이케아 검색창에 'desk'라고 입력하면
#
# https://www.ikea.com/kr/ko/search/?query=desk 로 저절로 변경이 된다.(주소가)
#
# 개발자 도구를 통해 살펴보면 페이지 넘버 버튼이 모두 pagenation이라는 class에 ``<div>``태그 아래에 있는 것을 확인할 수 있다.

# %%
import requests
from bs4 import BeautifulSoup

# HTML 코드 받아오기
response = requests.get('https://www.ikea.com/kr/ko/search/?query=desk')

# BeautifulSoup 형태로 전환하기
soup = BeautifulSoup(response.text,'html.parser')

# 결과
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR" xml:lang="ko-KR" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title id="htmlTitle">검색결과 - IKEA</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="2019-12-11" name="date_published" scheme="W3CDTF"/>
# <meta content="noindex, follow" name="robots"/>
# <meta content="ko-KR" name="language" scheme="rfc1766"/>
# <meta content="-77" name="languageid"/>
# <meta content="53" name="store_id"/>
# <meta content="" name="description"/>
# <meta content="search" name="keywords"/>
# <meta content="KR" name="country"/>
# <meta content="검색결과 - IKEA" name="title"/>
# <meta content="Categories" name="category"/>
# <meta content="1535-1535" name="IRWStats.siteVersion"/>
# <meta content="search" name="IRWStats.pageType"/>
# <meta content="search" name="IRWStats.internalPageType"/>
# <meta content="search" name="IRWStats.productFindingMethod"/>
# <meta content="Search" name="IRWStats.category"/>
# <meta content="Search" name="IRWStats.categoryLocal"/>
# <meta content="products" name="IRWStats.subCategory"/>
# <meta content="제품" name="IRWStats.subCategoryLocal"/>
# <meta content="Search result 1" name="IRWStats.chapter"/>
# <meta content="Search result 1" name="IRWStats.chapterLocal"/>
# <meta content="yes" name="IRWStats.searchVisited"/>
# <meta content="298" name="IRWStats.nofSearchResultsProduct"/>
# <meta content="303" name="IRWStats.nofSearchResultsTotal"/>
# <script language="JavaScript" src="//tags.tiqcdn.com/utag/ikea/kr-main/prod/utag.sync.js" type="text/javascript"></script>
# <script language="JavaScript" src="/ms/js/1535/js_main.js" type="text/javascript"></script>
# <script language="JavaScript" src="/ms/ko_KR/js/navOptions.js" type="text/javascript"></script>
# <script language="JavaScript" type="text/javascript">
#     var irwstats_locale = "ko_KR";
#     irwstatPrepareOmnitureConfig(irwstats_locale, "live");
# </script>
# <link href="/ms/css/1535/css_main.css" rel="stylesheet" type="text/css"/>
# <link href="/ms/ko_KR/css/local_em.css" id="localCSS" rel="stylesheet" type="text/css"/>
# <script language="javascript" type="text/javascript">
# 	//call the irwInit function in general.js
# 	irwInit();
# </script>
# <script language="javascript" type="text/javascript">
# 	//call the lastUrlCookie fn from cookie_util.js
# 	storeUrlForBackShopping();
# </script>
# <script type="text/javascript">
# 	// Variables needed for add to shopping list/shopping cart popup
# 	var js_fn_CHOICE_VIEW_LIST = "위시리스트 보기";
# 	var js_fn_CHOICE_MORE_PRODUCT_LIST = "다음에 제품이 추가됨";
# 	var js_fn_MOREPRODUCTS_HEADER = "제품이 추가됨";
# 	var js_fn_MOREPRODUCTS_ERROR_HEADER = "오류";
# 	var js_fn_MOREARTICLES_ERROR_TEXT = "제품";
# 	var js_fn_POPUP_SELECT_HEADER = "리스트 선택";
# 	var js_fn_POPUP_DONE_HEADER = "제품이 추가됨";
# 	var js_fn_POPUP_DONE_TEXT = "";
# 	var js_fn_POPUP_SAVE_BTN = "저장";
# 	var js_fn_POPUP_CLOSE_BTN = "닫기";
# 	var js_fn_POPUP_CANCEL_BTN = "닫기";
# 	var js_fn_POPUP_ERROR_HEADER = "오류가 발생했습니다.";
# 	var js_fn_POPUP_ERROR_TEXT = "죄송합니다. 고객님의 요청을 처리하는 중 오류가 발생했습니다.";
# 	var js_fn_POPUP_LOGIN_HEADER = "로그인";
# 	var js_fn_POPUP_LOGIN_LINK = "로그인";
# 	var js_fn_POPUP_SIGNUP_LINK = "회원가입";
# 	var js_fn_POPUP_LOGIN_TEXT = "새로운 위시리스트를 생성하거나, 현 리스트를 저장하려면 <a class=\"link\" rel=\"nofollow\" href=\"/webapp/wcs/stores/servlet/LogonForm?storeId=53&langId=-77&URL=/kr/ko/search/?query=desk\">로그인</a>하거나 <a class=\"link\" rel=\"nofollow\" href=\"/webapp/wcs/stores/servlet/CreateUser?storeId=53&langId=-77&URL=/kr/ko/search/?query=desk\">회원가입</a>하세요.";
# 	var js_fn_DEFAULT_LISTNAME = "위시리스트";
# 	var js_fn_POPUP_ERROR_MAX_NO_OF_LISTS = "만들 수 있는 최대 리스트 수를 초과했습니다.";
# 	var js_fn_SHOPPING_CART  = "장바구니 보기";
# 	var js_fn_HASBEENADDEDTOSC = "나의 장바구니에 추가되었습니다.";
# 	var js_fn_COULDNOTBEADDEDTOSC = "장바구니에 추가할 수 없습니다. 나중에 다시 시도해 주세요.";
# 	var js_fn_POPUP_PRODUCTADDED = "제품이 장바구니에 추가되었습니다.";
# 	var js_fn_POPUP_VIEWCART_URL = "/webapp/wcs/stores/servlet/OrderItemDisplay?storeId=53&langId=-77&catalogId=11001&orderId=.&newLinks=true";
# 	var js_fn_ERROR_CREATE_LIST = "죄송합니다. 리스트를 만드는 중 오류가 발생했습니다.";
# 	var js_fn_ERROR_SHOPPING_LIST_MAX_ITEM_QUANTITY_LIMIT_EXCEEDED = "제품에 대한 최대 수량은 999입니다.";
# 	var js_fn_ERROR_SHOPPING_LIST_MAX_LIMIT_EXCEEDED = "리스트에 담을 수 있는 최대 제품 수를 초과했습니다. ";
# 	var js_fn_POPUP_CART_PRODUCTS = "product(s)";
# 	var js_fn_POPUP_CART_TOTAL_PRICE = "Total price";
# 	var js_fn_OI_txt_inclVat = "부가세 포함<br>";
# 	var js_fn_OI_txt_exclVat = "부가세 제외<br>";
# 	var js_fn_OI_txt_POPUP_inclVat = "Total price Including VAT";
# 	var js_fn_OI_txt_POPUP_exclVat = "Total price Excluding VAT";
# 	var js_fn_TXT_PRICE = "가격/";
# 	var js_fn_UNIT_MEASURE_EN = "";
# 	var js_fn_TXT_UNITPRICE = "단가";
# 	var js_fn_defaultLocalStore_txt = "IKEA 매장 선택";
#     var js_ERR_PAY_COMMUNICATION_DISTR = "Communication with the payment processor failed while processing the transaction. Please try again or contact IKEA";
#     var js_ENABLE_STOCK_UNIT = "true";
# 	var js_ENERGY_PRODUCT_FICHE = "제품정보<br>";
# 	var sprTechInfoTabText =  "&nbsp;";
# 	var js_fn_New_Logo_Text =  "New";
# 	// Start of IKEA01102614
# 	var js_fn_GUEST_CHECKOUT_DISABLED = false;
# 	var js_fn_POPUP_SC_LOGIN_LINK_URL = "/webapp/wcs/stores/servlet/LogonForm?storeId=53&langId=-77&URL=/kr/ko/search/?query=desk";
# 	var js_fn_POPUP_SC_LOGIN_TEXT = "하기";
# 	var js_fn_POPUP_SC_SIGNUP_LINK_URL = "/webapp/wcs/stores/servlet/CreateUser?storeId=53&langId=-77&URL=/kr/ko/search/?query=desk";
# 	var js_fn_POPUP_SC_SIGNUP_LINK = "회원가입";
# 	var js_fn_POPUP_SC_SIGNUP_TEXT = "하러가기";
# 	// End of IKEA01102614
# 	var isRatingAndReviewEnabled = true;
# 	var js_fn_RESTOCK_WINDOW = 7;
#
# 		var js_fn_SLIDE_SHOW_ENABLED = true;
# 		// Slide show information
# 	   	var js_fn_PRICE_PER_PACKAGE = "가격/패키지";
#    		var js_fn_SHOW_SLIDE_SHOW = "슬라이드쇼";
#    		var js_fn_SLIDE_SHOW_MORE_INFO = "더 자세한 정보를 보려면 여기를 클릭하세요.";
#    		var js_fn_SLIDE_SHOW_CLOSE = "닫기";
#    		var js_fn_SLIDE_SHOW_PREV = "이전 제품({0}/{1})";
#    		var js_fn_SLIDE_SHOW_NEXT = "다음 제품({0}/{1})";
#    		var js_fn_MORE_OPTIONS = "다른 옵션 사용 가능";
#    		var js_fn_MORE_OPTIONS_FOR = "기타 {0} 옵션";
#    		var js_fn_IKEA_FAMILY = "IKEA Family 특별가";
#    		var js_fn_REGULAR_PRICE = "정가";
#    		var js_fn_ALL_PRODUCTS_NEW = "최신";
#    		var js_fn_WEE_PRF = "PRF";
#    		var js_fn_WEE_LESSPRF = "Less PRF";
#    		var js_fn_BUY_ONLINE = "구매하기";
#    		var js_fn_SAVE_TO_SHOPPING_LIST = "위시리스트에 추가";
#    		var js_fn_Non_BUY_ONLINE = "온라인 일시 품절";
#    		var js_fn_MORE_PRODUCTS = "기타  제품";
# 		// Javascript array to be used by the litebox slideshow in product listings
#
# 			var js_fn_SLIDE_SHOW_IDS = ["S29245101","40165466","00302597","70458000","80354281","90403506","S69217506","S49282630","S19281019","60221353","40446396","80250250","S19245192","60278288","S49246449","S49246487","S79216653","S49222448","00439473","S79217493","S09223322","00354275","30354274","40354278","30361024"];
#
# 		var js_fn_CAL_LEGAL_TEXT = "In compliance with California Title 20 regulations, product prices and features may vary in the state of California.";
# 		var js_fn_CAL_URL_TEXT = "자세한 내용은 가까운 IKEA 매장에서 확인하세요.";
# 		var js_fn_CAL_URL_REF = "http://info.ikea-usa.com/StoreLocator/StoreLocator.aspx";
# 		var js_fn_CAL_MORE_INFO = "More information";
# 		var js_fn_NLP_PREV_PRICE_CROSSOVER_ENABLED = true;
# 		var js_fn_TRO_PREV_PRICE_CROSSOVER_ENABLED = true;
#
# 		var js_fn_INSTEAD_OF = "정가 ";
# 		var js_fn_DISCLAIMER = "재고 소진 시까지 (1인당 최대 5개 한정)";
# 		var localeShortMonths = ["1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월",""];
# 		var isMonthFirst= 'true';
# 		var js_fn_ECO_FEE = "&nbsp;";
# 		var js_fn_FEE_INCLUDING_TXT = "&nbsp;";
# 		var js_fn_PLANNER_LINK_TEXT = "나만의 콤비네이션 만들기";
# 		var datePattern = "yyyy.MM.dd";
# 		var js_fn_currencySuperscriptingEnabled = false;
# 		var js_fn_isRScurrency = "KRW";
#
# </script>
# <script type="text/javascript">
# <!--
# 	var mQuery = "desk";
#
# 	var js_fn_FILTER_MESSAGES = [];
# 	js_fn_FILTER_MESSAGES['default'] = [];
# 	js_fn_FILTER_MESSAGES['default']['more'] = "자세히 표시";
# 	js_fn_FILTER_MESSAGES['default']['less'] = "간단히 표시";
# 	js_fn_FILTER_MESSAGES['filter_color'] = [];
# 	js_fn_FILTER_MESSAGES['filter_color']['more'] = "색상 자세히 표시";
# 	js_fn_FILTER_MESSAGES['filter_color']['less'] = "색상 간단히 표시";
# 	js_fn_FILTER_MESSAGES['filter_subcategory'] = [];
# 	js_fn_FILTER_MESSAGES['filter_subcategory']['more'] = "서브 카테고리 자세히 표시";
# 	js_fn_FILTER_MESSAGES['filter_subcategory']['less'] = "서브 카테고리 간단히 표시";
# 	js_fn_FILTER_MESSAGES['filter_department'] = [];
# 	js_fn_FILTER_MESSAGES['filter_department']['more'] = "전체 카테고리 자세히 표시";
# 	js_fn_FILTER_MESSAGES['filter_department']['less'] = "전체 카테고리 간단히 표시";
#
# 	var mMinPriceRange = 2500;
# 	var mMaxPriceRange = 1558000;
# 	var js_fn_PRICE_RANGE_ERROR_INVALID_RANGE = "유효하지 않은 가격 범위";
# 	var js_fn_PRICE_RANGE_ERROR_INVALID_NUMBER = "가격범위가 유효하지 않습니다.";
# 	var mNoHitsDueToFilter = false;
# 	var datePattern = "yyyy.MM.dd";
# //	-->
# </script>
# <script language="JavaScript" src="/ms/js/1535/IrwSearch.js" type="text/javascript"></script>
# <script language="JavaScript" src="/ms/js/moreOption.js" type="text/javascript"></script>
# <link href="/ms/css/1535/search_page_em.css" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
#   <link rel="stylesheet" href="/ms/css/1535/ie.css" type="text/css"/>
# <![endif]-->
# <!--[if IE 7]>
#   <script type="text/javascript" src="/ms/js/1535/ie7.js"></script>
#   <link rel="stylesheet" href="/ms/css/1535/ie7.css" type="text/css"/>
# <![endif]-->
# <!--[if IE 6]>
#   <link rel="stylesheet" href="/ms/css/1535/ie6.css" type="text/css"/>
# <![endif]-->
# <!--[if lt IE 6]>
#   <link rel="stylesheet" href="/ms/css/1535/ie5_5.css" type="text/css"/>
# <![endif]-->
# <!--[if lte IE 6]>
#   <script src="/ms/js/1535/iepngfix_tilebg.js" type="text/javascript"></script>
# <![endif]-->
# </head>
# <body onload="">
# <div xmlns:tns="http://www.w3.org/1999/xhtml"><a class="skipToMainContent" href="#mainContent">메인 화면으로 건너뛰기</a></div><div id="allContent"><div id="mainPadding">
# <script type="text/javascript">
# <!-- INCLUDE TEALIUM UTAG.JS ASYNCHRONOUSLY FOR IN THE BEGINNING OF BODY -->
# // part in bold should be configurable in settings per market
#  (function(a, b, c, d) {
#   a = '//tags.tiqcdn.com/utag/ikea/kr-main/prod/utag.js';
#   b = document;
#   c = 'script';
#   d = b.createElement(c);
#   d.src = a;
#   d.type = 'text/java' + c;
#   d.async = true;
#   a = b.getElementsByTagName(c)[0];
#   a.parentNode.insertBefore(d, a);
# })();
# <!-- INCLUDE TEALIUM UTAG.JS ASYNCHRONOUSLY FOR IN THE BEGINNING OF BODY -->
# </script>
# <div class="access" title="The access keys enabled are:">
# </div>
# <div class="topMenu" id="topMenu">
# <form action="/webapp/wcs/stores/servlet/LogonForm" id="myAccount" method="get">
# <div>
# <input name="storeId" type="hidden" value="53"/>
# <input name="langId" type="hidden" value="-77"/>
# <input name="catalogId" type="hidden" value="11001"/>
# </div>
# </form>
# <div class="logoContainer">
# <a class="logoLink" href="/kr/ko/" id="lnkIKEALogoHeader">
# <img alt="안녕하세요. IKEA Korea 입니다." class="logo" id="imgIKEALogoHeader" src="/ms/img/header/ikea-logo.svg"/>
# </a>
# <div class="searchForm">
# <form accept-charset="utf-8,*" action="/kr/ko/search/" id="searchForm" method="get" onsubmit="return checkSearch(this)">
# <div class="formInput">
# <label class="visuallyhidden" for="search ">검색 </label>
# <input id="search" name="query" placeholder="검색" type="text" value=""/>
# </div>
# <div class="formBtn">
# <script type="text/javascript">
#                                         //<![CDATA[
#                                             createButton('검색', 'lnkSearchBtnHeader', '', function() { search('searchForm'); });
#                                         //]]>
#                                     </script>
# <noscript>
# <div class="buttonContainer"><a href="javascript:void(0);"><span class="buttonLeft"> </span><span class="buttonCaption"><input id="lnkSearchBtnHeader" type="submit" value="검색"/></span><span class="buttonRight"> </span></a></div>
# </noscript>
# </div>
# </form>
# </div>
# <div class="ikeaTagline" id="txtIKEATagHeader"></div>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     var storeId='53';
#                                     var userInfo = getUserInfo('53','normal');
#                                     document.observe('dom:loaded', function() {
#                                         userInfo = getUserInfo('53');
#                                         updateWelcomeText();
#                                         updateNoOfCartItems('53');
#                                         generateScLinkListener('53');
#                                     });
#                                     function updateWelcomeText() {
#                                         var userLoggedIn = '{title} {lastname} {firstname}님! 안녕하세요.';
#                                         var userNotLoggedIn = '안녕하세요. IKEA Korea 입니다.';
#                                         if(userInfo != null && userInfo.firstName!= "" && userInfo.firstName!= "") {
#                                             userLoggedIn = userLoggedIn.replace(/{firstname}/g,userInfo.firstName.escapeHTML());
#                                             userLoggedIn = userLoggedIn.replace(/{lastname}/g,userInfo.lastName.escapeHTML());
#                                             userLoggedIn = userLoggedIn.replace(/{title}/g,userInfo.title.escapeHTML());
#                                             document.getElementById("txtIKEATagHeader").innerHTML = userLoggedIn;
#                                         }else{
#                                             document.getElementById("txtIKEATagHeader").innerHTML = userNotLoggedIn;
#                                         }
#                                     }
#                                 //]]>
#                             </script>
# </div>
# <div class="rightSection">
# <div class="iconLinkContainer">
# <div class="iconLink">
# <a href="/ms/ko_KR/customer-service/how-to-shop/howtoshop_map.html" id="lnkIcon1Header">
# <img alt=" " src=" "/>
# <span> </span>
# </a>
# </div>
# </div>
# <div class="linkList">
# <ul>
# <li>
# <a class="arrowLink" href="https://www.ikea.com/kr/ko/store.html" id="link_header_store">매장안내</a>
# </li>
# <li>
# <a class="arrowLink arrowLinkActive" href="http://ikeafamily.kr/" id="link_header_ikeafamily">IKEA FAMILY</a>
# </li>
# <li>
# <a class="arrowLink" href="/webapp/wcs/stores/servlet/InterestItemDisplay?storeId=53&amp;langId=-77" id="link_header_shopping_list" rel="nofollow">나의 쇼핑리스트</a>
# </li>
# </ul>
# </div>
# <div class="linkList">
# <ul>
# <li>
# <script type="text/javascript">
#                                         //<![CDATA[
#                                         if(haslogoffURL('53')) {
#                                             document.writeln("<a class='arrowLink' id='link_header_logout' href='/webapp/wcs/stores/servlet/Logoff?langId=-77&amp;storeId=53&amp;flow=LogoutFlow&amp;rememberMe=true' rel='nofollow'>로그아웃</a>");
#                                         }else{
#                                             document.writeln("<a class='arrowLink' id='link_header_login' href='javascript:logonLink();' rel='nofollow'>로그인</a>");
#                                         }
#                                         //]]>
#                                     </script>
# </li>
# <li>
# <a class="arrowLink" href="/webapp/wcs/stores/servlet/UpdateUser?storeId=53&amp;langId=-77" id="link_header_update_user" rel="nofollow">내 프로필</a>
# </li>
# <li>
# <a class="arrowLink" href="/webapp/wcs/stores/servlet/OrderItemDisplay?storeId=53&amp;langId=-77&amp;catalogId=11001&amp;orderId=.&amp;priceexclvat=&amp;newLinks=true" id="link_header_shopping_cart" rel="nofollow">쇼핑카트</a>
# <a class="arrowLink arrowLinkInactive" href="/webapp/wcs/stores/servlet/OrderItemDisplay?storeId=53&amp;langId=-77&amp;catalogId=11001&amp;orderId=.&amp;priceexclvat=&amp;newLinks=true" rel="nofollow"><span id="noOfCartItems"></span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div id="menu">
# <div class="mainMenu">
# <div class="tableContainer">
# <nav class="menu" role="navigation">
# <ul>
# <li class="allProducts" id="allProducts">
# <a href="/kr/ko/catalog/allproducts/" id="lnkMainMenu1Header">
# <span>모든 제품</span>
# </a>
# </li>
# <li class="newAtIkea">
# <a href="/kr/ko/catalog/news/departments/" id="lnkMainMenu2Header">
# <span>New</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/childrens_ikea/" id="lnkMainMenu3Header" onclick="checkhdr(this.id)">
# <span>어린이 IKEA</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/cooking/" id="lnkMainMenu4Header" onclick="checkhdr(this.id)">
# <span>조리</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/eating/" id="lnkMainMenu5Header" onclick="checkhdr(this.id)">
# <span>식기</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/living_room/" id="lnkMainMenu6Header" onclick="checkhdr(this.id)">
# <span>거실</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/workspaces/" id="lnkMainMenu7Header" onclick="checkhdr(this.id)">
# <span>홈오피스</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/bedroom/" id="lnkMainMenu8Header" onclick="checkhdr(this.id)">
# <span>침실</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/Textiles/" id="lnkMainMenu9Header" onclick="checkhdr(this.id)">
# <span>텍스타일/러그</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/bathroom/" id="lnkMainMenu10Header" onclick="checkhdr(this.id)">
# <span>욕실</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/ikea_kitchens/" id="lnkMainMenu11Header" onclick="checkhdr(this.id)">
# <span>주방</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/catalog/categories/departments/dining/" id="lnkMainMenu12Header" onclick="checkhdr(this.id)">
# <span>다이닝</span>
# </a>
# </li>
# <li>
# <a href="/kr/ko/Local_homepage/homeideas.html?icid=iba|kr|hfideas|201512140207497557_1" id="lnkMainMenu13Header" onclick="checkhdr(this.id)">
# <span>홈퍼니싱 아이디어</span>
# </a>
# </li>
# <!--<li style="width: 161px;"></li>-->
# <li class="moreRooms" id="moreRooms">
# <a href="#" id="lnkMainMenu14Header">
# <span>전체 카테고리</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <img alt="" class="mainMenuShadow" src="/ms/img/header/main_menu_shadow.gif"/>
# </div>
# <!-- prints the all departments menu -->
# <script type="text/javascript">
#         //<![CDATA[
#             new_getProducts();
#             enableDepartmentLink();
#         //]]>
#         </script>
# <div id="main">
# <div id="prfinfo">
# <div class="headline">
# 					Product Recycling Fund
# 				</div>
# <div class="body">
# 					The price of this item includes a contribution to a Product recycling fund to ensure that waste electrical and electronic equipment is collected and recycled in a responsible manner.
# 				</div>
# <div class="link">
# <a href="https://www.ikea.com/kr/ko/">IKEA Home Furnishing</a>
# </div>
# <div class="btns">
# <script type="text/javascript">
# 						createButton("Close", "prfbtn", "", function() { closePrfPopup(); });
# 					</script>
# </div>
# </div>
# <a name="mainContent"></a>
# <div class="serpLeftMenu" id="serpLeftMenu">
# <h1 class="headerLeftNavi">검색결과<script src="https://www.newideas.kr/js_cont/jquery-1.11.0.min.js" type="text/javascript"></script><script type="text/javascript">var $J = jQuery.noConflict();</script><script src="https://www.newideas.kr/js_cont/personalized/irw_ko/personalized.js" type="text/javascript"></script></h1>
# <h2 class="serpTabActive">
# <a class="serpTabActive" href="/kr/ko/search/?query=desk" id="active-1" onclick="irwstatSetTrailingTag('IRWStats.pagename', 'search&gt;products&gt;search result 1');
# 		    				irwstatSetTrailingTag('IRWStats.subcategory', 'search&gt;products');
# 		    				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;search_type');
# 		    				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;search_type&gt;products');">
# 						제품 (298)
# 					</a>
# </h2>
# <span class="serpTabInActive">
# <a class="serpTabInActive" href="/kr/ko/search/?query=desk&amp;category=ideas" id="active-2" onclick="irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;search_type');
# 		    			 	irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;search_type&gt;inspiration');">
# 						아이디어 (3)
# 		            </a>
# </span>
# <span class="serpTabInActive">
# <a class="serpTabInActive" href="/kr/ko/search/?query=desk&amp;category=other" id="active-3" onclick="irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;search_type');
# 						 	irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;search_type&gt;other_results');">
# 						기타 결과 (2)
# 			        </a>
# </span>
# <h3 class="serpFilterHeadline">색상</h3>
# <span class="serpFilterLnkActive">모두 보기</span>
# <div class="serpFilterList" id="filter_color">
# <ul>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%ea%b7%b8%eb%a0%88%ec%9d%b4" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uADF8\uB808\uC774');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #808080"> </span><span>그레이</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%ea%b7%b8%eb%a6%b0" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uADF8\uB9B0');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #008000"> </span><span>그린</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%eb%a0%88%eb%93%9c" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uB808\uB4DC');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #FF0000"> </span><span>레드</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%eb%a9%80%ed%8b%b0%ec%bb%ac%eb%9f%ac" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBA40\uD2F0\uCEEC\uB7EC');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: null"> </span><span>멀티컬러</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%eb%b2%a0%ec%9d%b4%ec%a7%80" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBCA0\uC774\uC9C0');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #F5F5DC"> </span><span>베이지</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%eb%b8%8c%eb%9d%bc%ec%9a%b4" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBE0C\uB77C\uC6B4');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #8B4513"> </span><span>브라운</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%eb%b8%94%eb%9e%99" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBE14\uB799');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #000000"> </span><span>블랙</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%eb%b8%94%eb%a3%a8" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBE14\uB8E8');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #0000FF"> </span><span>블루</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%ed%95%91%ed%81%ac" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uD551\uD06C');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #FFC0CB"> </span><span>핑크</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%ed%99%94%ec%9d%b4%ed%8a%b8" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uD654\uC774\uD2B8');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="color" style="background-color: #FFFFFF"> </span><span>화이트</span>
# </a>
# </li>
# <li class="colorRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;color=%ec%97%ac%eb%9f%ac+%ea%b0%80%ec%a7%80+%ec%83%89%ec%83%81" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC5EC\uB7EC \uAC00\uC9C0 \uC0C9\uC0C1');
# 		            				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 		            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;color');">
# <span class="multicolor" style="background-color: "> </span><span>여러 가지 색상</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="serpLine"></div>
# <h3 class="serpFilterHeadline">가격</h3>
# <form action="/kr/ko/search/" class="serpFilterForm" method="get" name="minMaxPrice" style="cursor: default;">
# <div class="content" id="minMaxPriceContent">
# <fielset class="searchPriceFilter">
# <input name="query" type="hidden" value="desk"/>
# <input name="category" type="hidden" value="products"/>
# <label class="serpMinPrice" for="minPrice">시작:</label><label class="serpMaxPrice" for="maxPrice">끝:</label>
# <input id="minPrice" maxlength="7" name="min_price" type="text" value="2500"/>
# <div id="priceFilterDash">-</div>
# <input id="maxPrice" maxlength="7" name="max_price" type="text" value="1558000"/>
# <input name="" type="hidden" value=""/>
# <div id="serpButtonContainer">
# <script type="text/javascript">
# 							createButton("보기","jsButton_narrowDownSearch_01", "button", function(e){
# 							irwstatSetTrailingTag('IRWStats.pageArea', 'search>search_result>narrow_down_result');
# 							irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search>search_result>narrow_down_result>price');});
# 						</script>
# <noscript>
# <div class="buttonContainer">
# <a class="button" href="#" id="irw_button"><div class="buttonLeft"> </div><div class="buttonCaption"><input type="submit" value="보기"/></div><div class="buttonRight"> </div></a>
# </div>
# </noscript>
# </div>
# </fielset></div></form></div></div></div></div></body></html>
#
# <div class="client-error-text" id="minMaxPriceError" style="display:none;"></div>
#
# <div class="serpFilterFormLnk">
# </div>
# <div class="serpLine"></div>
# <h3 class="serpFilterHeadline">제품 카테고리</h3>
# <span class="serpFilterLnkActive">모두 보기</span>
# <div class="serpFilterList" id="filter_subcategory">
# <ul id="1">
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=41790" onclick="irwstatSetTrailingTag('IRWStats.filter', 'PLATSA\x2F\uD50C\uB78F\uC0AC \uBAA8\uB4C8\uC218\uB0A9\uC2DC\uC2A4\uD15C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>PLATSA/플랏사 모듈수납시스템</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=18835" onclick="irwstatSetTrailingTag('IRWStats.filter', 'STUVA\x2F\uC2A4\uD22C\uBC14 \uC218\uB0A9\uC2DC\uC2A4\uD15C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>STUVA/스투바 수납시스템</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10475" onclick="irwstatSetTrailingTag('IRWStats.filter', 'TV\x2F\uBA40\uD2F0\uBBF8\uB514\uC5B4\uAC00\uAD6C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>TV/멀티미디어가구</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=29882" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uAC70\uC2E4\uC218\uB0A9\uC2DC\uC2A4\uD15C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>거실수납시스템</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=30454" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uAC70\uC2E4\uC7A5\x2F\uCC2C\uC7A5\x2F\uCF58\uC194\uD14C\uC774\uBE14');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>거실장/찬장/콘솔테이블</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=18701" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uAE30\uC800\uADC0\uAD50\uD658\uB300\x2F\uC561\uC138\uC11C\uB9AC');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>기저귀교환대/액세서리</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=19039" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uB85C\uD504\uD2B8\x2F2\uCE35\uCE68\uB300');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>로프트/2층침대</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=20503" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBCBD\uBD80\uCC29\uB4F1');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>벽부착등</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10398" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBCBD\uC120\uBC18');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>벽선반</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=37900" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uBCBD\uC218\uB0A9');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>벽수납</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10711" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC11C\uB78D\uC720\uB2DB');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>서랍유닛</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10551" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC11C\uB958\x2F\uBBF8\uB514\uC5B4\uC815\uB9AC\uC6A9\uD488');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>서류/미디어정리용품</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=11465" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC120\uBC18\uC720\uB2DB');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>선반유닛</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=18706" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC218\uB0A9\uAC00\uAD6C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>수납가구</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=46052" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC218\uB0A9 \uC194\uB8E8\uC158 \uC2DC\uC2A4\uD15C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>수납 솔루션 시스템</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10384" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC218\uB0A9\uC7A5\x2F\uC7A5\uC2DD\uC7A5');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>수납장/장식장</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10550" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC218\uB0A9\uD568\x2F\uBC14\uAD6C\uB2C8');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>수납함/바구니</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=20506" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC2A4\uD3FF\uC870\uBA85');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>스폿조명</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=21825" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC2DD\uD0C1');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>식탁</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=18767" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC5B4\uB9B0\uC774 \uAC00\uAD6C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>어린이 가구</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=24711" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC5B4\uB9B0\uC774 \uC7A5\uC2DD\uD488\x2F\uAD00\uB828\uC6A9\uD488');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>어린이 장식품/관련용품</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=18723" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC5B4\uB9B0\uC774 \uCE68\uB300');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>어린이 침대</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=45780" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC601\uC544\uC6A9 \uAC00\uAD6C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>영아용 가구</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=19053" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC637\uC7A5');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>옷장</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=20502" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC791\uC5C5\uB4F1');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>작업등</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=16195" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC804\uC120\uC815\uB9AC\x2F\uAD00\uB828\uC6A9\uD488');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>전선정리/관련용품</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=16292" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC870\uB9BD\uACF5\uAD6C');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>조립공구</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=25227" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC885\uC774\uC81C\uD488');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>종이제품</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10471" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uC8FC\uBC29\uC544\uC77C\uB79C\uB4DC\x2F\uCE74\uD2B8');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>주방아일랜드/카트</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=20649" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uCC45\uC0C1\x2F\uCEF4\uD4E8\uD130\uCC45\uC0C1');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>책상/컴퓨터책상</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10382" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uCC45\uC7A5');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>책장</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=20656" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uCE68\uB300\uD611\uD0C1');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>침대협탁</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=46080" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uCE78\uB9C9\uC774');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>칸막이</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10705" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uCEE4\uD53C\uD14C\uC774\uBE14\x2F\uBCF4\uC870\uD14C\uC774\uBE14');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>커피테이블/보조테이블</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=40845" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uCF00\uC774\uBE14 \x26 \uCDA9\uC804\uAE30');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>케이블 &amp; 충전기</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=10712" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uD14C\uC774\uBE14\uC0C1\uD310\x2F\uB2E4\uB9AC');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>테이블상판/다리</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=20657" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uD654\uC7A5\uB300');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>화장대</span>
# </a>
# </li>
# <li class="catRow eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;range_subcategory=40843" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uD734\uB300\uD3F0 \x26 \uD0DC\uBE14\uB9BF \uC561\uC138\uC11C\uB9AC');
# 				           					irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 				            				irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;categories');">
# <span>휴대폰 &amp; 태블릿 액세서리</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="serpLine"></div>
# <h3 class="serpFilterHeadline">카테고리</h3>
# <span class="serpFilterLnkActive">모두 보기</span>
# <div class="serpFilterList" id="filter_department">
# <ul>
# <li class="topCat eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;department=home_electronics" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uAC00\uC804');
# 			           				irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;narrow_down_result');
# 			            			irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;narrow_down_result&gt;catName');">
# <span>가전</span>
# </a>
# </li>
# <li class="topCat eS-click eS-t--">
# <a href="/kr/ko/search/?query=desk&amp;category=products&amp;department=living_room" onclick="irwstatSetTrailingTag('IRWStats.filter', '\uAC70\uC2E4');
# ...
# </div>
# <div class="ratingsCountContainer" style="float: left;width: 20%;display: table;">
# <a class="ratingsCount" href="/kr/ko/catalog/products/40354278/?bvtab">(58)</a>
# </div>
# </div>
# <span class="txtDim1Product0 prodDimension">
# 	   	         폭: 142 cm
# 	   	         </span>
# <span class="txtDim1Product1 prodDimension">
# 	   	         깊이: 50 cm
# 	   	         </span>
# <span class="txtDim1Product2 prodDimension">
# 	   	         높이: 75 cm
# 	   	         </span>
# <div class="compare"><input id="compare_40354278" type="checkbox"/><label for="compare_40354278">비교하기</label></div>
# <div class="buttonsContainer eS-addingToCart eS-t-Oy9zZWFyY2gtYWxsL3Byb2R1Y3QtcmVzdWx0L3NlYXJjaC1oaXRzLXdpdGgtY291bnQvc2VhcmNoLWhpdHM7Iztwcm9kdWN0X2tleTsxMzcxOF9rb19LUjsxMzcxOF80MDM1NDI3OF9rb19LUjtPQkpFQ1RJVkUkO05PTkU6Tk9ORTs4OTs">
# <div class="buttonContainer"><a class="button" href="#" id="popupAddToCart40354278" onclick="activateShopListPopup('addToCart',$('popupAddToCart40354278'),53,-77,'₩ 99,900 /개');return false;"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="#" id="popupShoppingList40354278" onclick="activateShopListPopup('add',$('popupShoppingList40354278'),53,-77,'₩ 99,900 /개');return false;">위시리스트에 추가</a>
# </div>
# </div>
# <noscript>
# <span class="txtDim1Product0 prodDimension">
# 	   	         폭: 142 cm
# 	   	         </span>
# <span class="txtDim1Product1 prodDimension">
# 	   	         깊이: 50 cm
# 	   	         </span>
# <span class="txtDim1Product2 prodDimension">
# 	   	         높이: 75 cm
# 	   	         </span>
# </noscript>
# </div>
# </div>
# </div>
# <div class="productContainerNoBorder oldTd">
# <div class="productContainer" id="item_30361024_25">
# <div class="parentContainer">
# <div class="productPadding eS-click eS-t-Oy9zZWFyY2gtYWxsL3Byb2R1Y3QtcmVzdWx0L3NlYXJjaC1oaXRzLXdpdGgtY291bnQvc2VhcmNoLWhpdHM7Iztwcm9kdWN0X2tleTsyNzg5Nl9rb19LUjsyNzg5Nl8zMDM2MTAyNF9rb19LUjtPQkpFQ1RJVkUkO05PTkU6Tk9ORTs4OTs">
# <a href="/kr/ko/catalog/products/30361024/" onclick="irwStatTopProductClicked();">
# <img alt="" border="0" class="prodImg" id="imgThmbProduct25" src="/kr/ko/images/products/arkelstorp-aleukelseutoleupeu-chaegsang__0735967_PE740301_S2.JPG"/>
# <h4 class="prodHeader">
# <span class="prodName prodNameTro" id="txtNameProduct25">ARKELSTORP 아르켈스토르프</span>
# <div>
# <span class="prodDesc" id="txtDescrProduct25" style="display:inline;">책상
#
# 				</span>
# </div>
# </h4>
# <span class="prodPrice" id="txtPriceProduct25" style="clear:both;">
# 				₩ 249,000 /개<!--<span class="perProduct"> &nbsp;/개</span>-->
# </span>
# <div class="comparisonContainer" style="display: none">
# <span>
#
# 				단가
# 			</span>
# <span class="packagepricevaluebold comparisonPrice"></span>
# </div>
# </a>
# </div>
# <div class="cartContainer moreInfo" id="cartContainer30361024">
# <div class="ratingsContainer">
# <div class="ratingStarsContainer" style="float: left;width: 80%;">
# <div class="ratingStarsOffLarge">★★★★★</div>
# <div class="ratingStarsOnLarge" style="width:96.0%">★★★★★</div>
# </div>
# <div class="ratingsCountContainer" style="float: left;width: 20%;display: table;">
# <a class="ratingsCount" href="/kr/ko/catalog/products/30361024/?bvtab">(13)</a>
# </div>
# </div>
# <span class="txtDim1Product0 prodDimension">
# 	   	         폭: 140 cm
# 	   	         </span>
# <span class="txtDim1Product1 prodDimension">
# 	   	         깊이: 70 cm
# 	   	         </span>
# <span class="txtDim1Product2 prodDimension">
# 	   	         높이: 74 cm
# 	   	         </span>
# <div class="compare"><input id="compare_30361024" type="checkbox"/><label for="compare_30361024">비교하기</label></div>
# <div class="buttonsContainer eS-addingToCart eS-t-Oy9zZWFyY2gtYWxsL3Byb2R1Y3QtcmVzdWx0L3NlYXJjaC1oaXRzLXdpdGgtY291bnQvc2VhcmNoLWhpdHM7Iztwcm9kdWN0X2tleTsyNzg5Nl9rb19LUjsyNzg5Nl8zMDM2MTAyNF9rb19LUjtPQkpFQ1RJVkUkO05PTkU6Tk9ORTs4OTs">
# <div class="buttonContainer"><a class="button" href="#" id="popupAddToCart30361024" onclick="activateShopListPopup('addToCart',$('popupAddToCart30361024'),53,-77,'₩ 249,000 /개');return false;"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="#" id="popupShoppingList30361024" onclick="activateShopListPopup('add',$('popupShoppingList30361024'),53,-77,'₩ 249,000 /개');return false;">위시리스트에 추가</a>
# </div>
# </div>
# <noscript>
# <span class="txtDim1Product0 prodDimension">
# 	   	         폭: 140 cm
# 	   	         </span>
# <span class="txtDim1Product1 prodDimension">
# 	   	         깊이: 70 cm
# 	   	         </span>
# <span class="txtDim1Product2 prodDimension">
# 	   	         높이: 74 cm
# 	   	         </span>
# </noscript>
# </div>
# </div>
# </div>
# </div>
# <noscript>
# <div class="oldTr">
# <div class="noJs oldTd">
# <div class="productContainer">
# <div class="cartContainer" id="">
# <div class="buttonsContainer">
# <div class="buttonContainer"><a class="button" href="/webapp/wcs/stores/servlet/OrderItemAdd?catEntryId=1085459&amp;quantity=1&amp;URL=OrderItemDisplay" rel="nofollow"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="/webapp/wcs/stores/servlet/IrwShoppingListNoJS?commandId=addItem&amp;langId=-77&amp;storeId=53&amp;catEntryId=1085459" rel="nofollow">위시리스트에 추가</a>
# </div>
# </div>
# </div>
# </div>
# <div class="noJs oldTd">
# <div class="productContainer">
# <div class="cartContainer" id="">
# <div class="buttonsContainer">
# <div class="buttonContainer"><a class="button" href="/webapp/wcs/stores/servlet/OrderItemAdd?catEntryId=1030268&amp;quantity=1&amp;URL=OrderItemDisplay" rel="nofollow"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="/webapp/wcs/stores/servlet/IrwShoppingListNoJS?commandId=addItem&amp;langId=-77&amp;storeId=53&amp;catEntryId=1030268" rel="nofollow">위시리스트에 추가</a>
# </div>
# </div>
# </div>
# </div>
# <div class="noJs oldTd">
# <div class="productContainer">
# <div class="cartContainer" id="">
# <div class="buttonsContainer">
# <div class="buttonContainer"><a class="button" href="/webapp/wcs/stores/servlet/OrderItemAdd?catEntryId=1030270&amp;quantity=1&amp;URL=OrderItemDisplay" rel="nofollow"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="/webapp/wcs/stores/servlet/IrwShoppingListNoJS?commandId=addItem&amp;langId=-77&amp;storeId=53&amp;catEntryId=1030270" rel="nofollow">위시리스트에 추가</a>
# </div>
# </div>
# </div>
# </div>
# <div class="noJs oldTd">
# <div class="productContainer">
# <div class="cartContainer" id="">
# <div class="buttonsContainer">
# <div class="buttonContainer"><a class="button" href="/webapp/wcs/stores/servlet/OrderItemAdd?catEntryId=1030277&amp;quantity=1&amp;URL=OrderItemDisplay" rel="nofollow"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="/webapp/wcs/stores/servlet/IrwShoppingListNoJS?commandId=addItem&amp;langId=-77&amp;storeId=53&amp;catEntryId=1030277" rel="nofollow">위시리스트에 추가</a>
# </div>
# </div>
# </div>
# </div>
# <div class="noJs oldTd productContainerNoBorder">
# <div class="productContainer">
# <div class="cartContainer" id="">
# <div class="buttonsContainer">
# <div class="buttonContainer"><a class="button" href="/webapp/wcs/stores/servlet/OrderItemAdd?catEntryId=1058459&amp;quantity=1&amp;URL=OrderItemDisplay" rel="nofollow"><div class="buttonLeft"> </div><div class="buttonCaption">구매하기</div><div class="buttonRight"> </div></a></div>
# <a class="listLink" href="/webapp/wcs/stores/servlet/IrwShoppingListNoJS?commandId=addItem&amp;langId=-77&amp;storeId=53&amp;catEntryId=1058459" rel="nofollow">위시리스트에 추가</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </noscript>
# <div class="compareRow oldTr" style="display: none;">
# <div class="compareContainer oldTd" id="parent_compare_S09223322">
# <div class="compare">
# <input id="display_compare_S09223322" type="checkbox"/>
# <label for="display_compare_S09223322">비교하기</label>
# </div>
# </div>
# <div class="compareContainer oldTd" id="parent_compare_00354275">
# <div class="compare">
# <input id="display_compare_00354275" type="checkbox"/>
# <label for="display_compare_00354275">비교하기</label>
# </div>
# </div>
# <div class="compareContainer oldTd" id="parent_compare_30354274">
# <div class="compare">
# <input id="display_compare_30354274" type="checkbox"/>
# <label for="display_compare_30354274">비교하기</label>
# </div>
# </div>
# <div class="compareContainer oldTd" id="parent_compare_40354278">
# <div class="compare">
# <input id="display_compare_40354278" type="checkbox"/>
# <label for="display_compare_40354278">비교하기</label>
# </div>
# </div>
# <div class="compareContainer productContainerNoBorder oldTd" id="parent_compare_30361024">
# <div class="compare">
# <input id="display_compare_30361024" type="checkbox"/>
# <label for="display_compare_30361024">비교하기</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="paginationContainer">
# <div class="pagination">
# <a class="active" href="#" onclick="return false;">1</a>
# <a href="/kr/ko/search/?query=desk&amp;pageNumber=2">2</a>
# <a href="/kr/ko/search/?query=desk&amp;pageNumber=3">3</a>
# <a href="/kr/ko/search/?query=desk&amp;pageNumber=4">4</a>
# <a href="/kr/ko/search/?query=desk&amp;pageNumber=5">5</a>
#
# 					... <a href="/kr/ko/search/?query=desk&amp;pageNumber=12">12</a>
# </div>
# <div class="buttons">
# <script type="text/javascript">
# 							//createButton("비교 표시", "jsButton_SortFilterBar_01", "button blueButton disabledButton", function(e){location.href = '/kr/ko/search/?compare=true&query=desk&catalogId=10001&langId=-77&storeId=53&isNewLink=true';
# 							//irwstatSetTrailingTag('IRWStats.pageArea', 'search>search_result>search_result_bar');
# 							//irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search>search_result>search_result_bar>compare');});
# 						</script>
# <div class="buttonContainer">
# <a class="jsButton_SortFilterBar_01 button blueButton disabledButton" href="#" onclick="location.href = '/kr/ko/search/?compare=true&amp;query=desk&amp;catalogId=10001&amp;langId=-77&amp;storeId=53&amp;isNewLink=true';irwstatSetTrailingTag('IRWStats.pageArea', 'search&gt;search_result&gt;search_result_bar');irwstatSetTrailingTag('IRWStats.detailedPageArea', 'search&gt;search_result&gt;search_result_bar&gt;compare'); return false;" style="display:none;">
# <div class="buttonLeft buttonLeftBlue"> </div><div class="buttonCaption buttonCaptionBlue">비교 표시</div><div class="buttonRight buttonRightBlue"> </div>
# </a>
# </div>
# <script type="text/javascript">
# 				jQuery(".jsButton_SortFilterBar_01").show();
# 			</script>
# <div class="buttonContainer">
# <a class="jsButton_SortFilterBar_02 button" href="#" onclick="slideshow.open(); return false;" style="display:none;">
# <div class="buttonLeft"> </div><div class="buttonCaption">슬라이드쇼</div><div class="buttonRight"> </div>
# </a>
# </div>
# <script type="text/javascript">
# 				if (js_fn_SLIDE_SHOW_ENABLED == true) {
# 					//createButton("슬라이드쇼", "jsButton_SortFilterBar_02", "button", function(e){ slideshow.open() });
# 					jQuery(".jsButton_SortFilterBar_02").css("display", "inline");
# 				}
# 			</script>
# </div>
# </div>
# <script type="text/javascript">
# 				setComparisonCheckboxStatus();
# 		 		displayOfNoJsContent();
# 			</script>
# </div>
# <div style="clear: both;"></div>
# <div id="footer">
# <div class="linksWrapper">
# <div class="linkContainer linkContainerFirst">
# <h2 class="header">
#
#                             쇼핑하기
#
#                     </h2>
# <a class="link" href="/ms/ko_KR/customer-service/about-shopping/catalogue-and-brochures/index.html?icid=iba|kr|catalogue_ft|201707260944259753_3">
#                                         온라인 카탈로그
#                                     </a>
# <a class="link" href="/ms/ko_KR/customer-service/buying-guides/index.html">
#                                         제품구매안내
#                                     </a>
# <a class="link" href="/ms/ko_KR/customer-service/how-to-shop/guide.html">
#                                         매장 가이드
#                                     </a>
# <a class="link" href="/ms/ko_KR/customer-service/guarantee/index.html">
#                                         IKEA 품질보증
#                                     </a>
# <a class="link" href="https://www.ikea.com/kr/ko/catalog/stockcheck/">
#                                         제품재고 확인
#                                     </a>
# <a class="link" href="/ms/ko_KR/service-offer/financing/index.html">
#                                         IKEA 카드 정보
#                                     </a>
# </div>
# <div class="linkContainer"><h2 class="header"><a href="/ms/ko_KR/customer-service/index.html">고객지원</a></h2><a href="/kr/ko/customerservices/faq">FAQ</a><a href="/ms/ko_KR/customer-service/contact-us/index.html">고객문의</a><a href="https://www.ikea.com/ms/ko_KR/customer-service/contact-us/index.html#fr_c_track">배송 조회</a><a href="/ms/ko_KR/customer-service/return-policy/index.html">반품정책</a><a href="/ms/ko_KR/customer-service/let-assemble/index.html">조립하기</a></div><div class="linkContainer"><h2 class="header"><a href="/ms/ko_KR/service-offer/index.html">IKEA 서비스</a></h2><a href="/ms/ko_KR/service-offer/delivery/index.html">배송 서비스</a><a href="/ms/ko_KR/service-offer/parcel/index.html">택배 서비스</a><a href="/ms/ko_KR/service-offer/home-furnishing-planning/index.html">홈퍼니싱 플래닝 서비스</a><a href="/ms/ko_KR/service-offer/office-planning/">온라인 플래닝</a><a href="/ms/ko_KR/service-offer/assembly/">조립 서비스</a><a href="/ms/ko_KR/service-offer/kitchen-installation/">주방&amp;욕실 설치 서비스</a></div><div class="linkContainer"><h2 class="header"><a href="/ms/ko_KR/this-is-ikea/index.html">IKEA 이야기</a></h2><a href="/ms/ko_KR/this-is-ikea/the-ikea-concept/index.html">IKEA 컨셉</a><a href="/ms/ko_KR/Local_homepage/Design_For_Everyone.html">데모크래틱 디자인</a><a href="/ms/ko_KR/this-is-ikea/about-the-ikea-group/index.html">IKEA 그룹 기업정보</a><a href="/ms/ko_KR/this-is-ikea/on-the-factory-floor/index.html">IKEA 작업현장</a><a href="/ms/ko_KR/this-is-ikea/ikea-highlights/index.html">IKEA 하이라이트</a><a href="/ms/ko_KR/this-is-ikea/people-and-planet/index.html">사람과 지구</a></div><div class="linkContainer"><h2 class="header"><a href="/ms/ko_KR/this-is-ikea/working-at-the-ikea-group/index.html">IKEA 그룹에서 일하기</a></h2><a href="/ms/ko_KR/this-is-ikea/available-jobs/">채용정보</a></div><div class="linkContainer lastLinkContainer"><h2 class="header"> 뉴스룸</h2><a href="/kr/ko/about_ikea/newsroom/">기업뉴스</a><a href="/ms/ko_KR/pressroom/index.html">제품뉴스</a><a href="/ms/ko_KR/this-is-ikea/reports-downloads/index.html">리포트 및 다운로드</a><a href="/ms/ko_KR/about_ikea/newsroom/product_recalls/index.html">제품리콜</a></div>
# <div class="clearAll"></div> <!-- IKEA00671879 -->
# </div>
# <div class="copyRight" id="txtCopyFooter">
#                 © Inter IKEA Systems B.V. 1999 - 2019
#
#
#                             <span class="linkDivider">|</span>
# <a href="/ms/ko_KR/privacy_policy/privacy_policy.html">
#                                 웹사이트이용약관
#                             </a>
# <span class="linkDivider">|</span>
# <a href="/ms/ko_KR/privacy_policy/20164_privacy_policy_ko.html">
# <span style="COLOR: #3232CD"><b>IKEA Korea 개인정보처리방침</b></span>
# </a>
# <span class="linkDivider">|</span>
# <a href="#none">
#                                 IKEA 고객지원센터 1670-4532
#                             </a>
# </div>
# </div>
# <div style="display:none;">
# <script type="text/javascript">
# 		irwstatSend();
# 	    </script>
# </div>
# <script src="/ms/js/1535/new_survey_popup.js" type="text/javascript"></script>
# <script src="/ms/js/1535/survey_global.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	document.observe('dom:loaded', function()
# 	{
# 	new ApptusEsales.Esales();
# 	});
# </script>
#
# <script type="text/javascript">var _cf = _cf || []; _cf.push(['_setFsp', true]); _cf.push(['_setBm', true]); _cf.push(['_setAu', '/resources/d154096bc2157225aec88575d39a4f']);</script><script src="https://www.ikea.com/resources/d154096bc2157225aec88575d39a4f" type="text/javascript"></script>

# %% [markdown]
# 코드는 살펴보지 pagenation 클래스를 갖는 ``<div>``태크 안에 ``<a>``태그들이 있고 가장 마지막 ``<a>``태그에 페이지번호가 있음을 확인
#
# * <a href="/kr/ko/search/?query=desk&amp;pageNumber=2">2</a>
#
# 여기서 총 12개의 페이지가 존재한다는 것을 확인
#
# 따라서 마지막 ``<a>``태그의 텍스트를 가져온다면 페이지 개수를 알아낼 수 있을 것

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.ikea.com/kr/ko/search/?query=desk')

soup = BeautifulSoup(response.text, 'html.parser')

page_length = soup.select('.pagination a')[-1].text   # 리스트의 마지막 변수에서 text만 추출하여 길이로 사용했다.

print(page_length)
# Out:
# 12

# %% [markdown]
# #### 위 값을 이용해서 for 반복문을 실행하면 실제 페이지 개수 만큼만 HTML코드를 받아올 수 있습니다.

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.ikea.com/kr/ko/search/?query=desk')

soup = BeautifulSoup(response.text, 'html.parser')

page_length = soup.select('.pagination a')[-1].text   # 리스트의 마지막 변수에서 text만 추출하여 길이로 사용했다.

pages = []

for i in range(1, int(page_length) + 1):
    response = requests.get('https://www.ikea.com/kr/ko/search/?query=desk&pageNumber=' + str(i))
    pages.append(response.text)
    
print(len(pages))
# Out:
# 12

# %% [markdown]
# ## 방법2: 일단 가져와서 확인해보기(더 스마트)
#
# 만약 전체 페이지 개수가 사이트에 드러나지 않는다면? (그런 경우가 있는듯)
# 일단은 페이지를 가져오고 데이터가 비어있는지 확인하는 방법이 있다.
#
# desk 검색결과에 833 페이지도 있을까?
#
# 일단 833 을 띄웠을 때 상품이 나와버리긴 하지만 일단 제품 이름인 prodName 클래스의 유무로 한 번 확인해보자

# %%
import requests
from bs4 import BeautifulSoup

# 빈 리스트 생성
pages = []

# 첫 페이지 번호 지정
page_num = 1

while True:
    # HTML 코드 받아오기
    response = requests.get("https://www.ikea.com/kr/ko/search/?query=desk&pageNumber=" + str(page_num))

    # BeautifulSoup 타입으로 변환하기
    soup = BeautifulSoup(response.text, 'html.parser')

    # ".prodName" 클래스가 있을 때만 HTML 코드를 리스트에 담기
    if len(soup.select('.pagination a')) > 0:
        pages.append(soup)
        page_num += 1
    else:
        break

# 가져온 페이지 개수 출력하기
print(len(pages))
# Out:
# 12

# %% [markdown]
# ## TV 시청률 크롤링
#
# 2010년 1월부터 2018년 12월까지 모든 달에 대해 데이터가 있는 모든 페이지의 HTML코드를
#
# **rating_pages**에 저장하기
# 단, **Beautiful Soup** 타입으로 변환한 코드가 아닌 **response**의 **text**를 저장하시오!

# %%
import requests
from bs4 import BeautifulSoup


pages = []



while True:
    response = requests.get('https://workey.codeit.kr/ratings/index?' + str(page_num))
    soup = BeautifulSoup(reponse.text, 'html.parser')
    if len(soup.select('.rank') > 0):
